# %% [markdown]
# <a href="https://colab.research.google.com/github/vijji5432/Timetable_generator/blob/main/Vizuara.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install xlsxwriter
# Out:
# Requirement already satisfied: xlsxwriter in /usr/local/lib/python3.10/dist-packages (3.2.0)

# %%
import pandas as pd
import random
import xlsxwriter

# Step 1: Load the Excel file and read the sheets
data_path = '/content/TimeTable Project.xlsx'
data = pd.ExcelFile(data_path)

# %%
# Step 2: Read the sheets for period allotment and teacher-subject mapping
period_allotment = data.parse('Period Allotment')
teacher_subject_mapping = data.parse('Teacher-Subject Mapping')
home_teachers_df = data.parse('Teacher Subject Mapping 2')
teacher_subject_mapping.columns = teacher_subject_mapping.columns.str.strip()
teacher_subject_mapping.rename(columns={"I A": "IA"}, inplace=True)

# %%
# Step 3: Inspect the sheets to ensure data is loaded correctly
period_allotment['Jr. KG'] = pd.to_numeric(period_allotment['Jr. KG'], errors='coerce')
period_allotment['Sr. KG'] = pd.to_numeric(period_allotment['Sr. KG'], errors='coerce')
period_allotment['I'] = pd.to_numeric(period_allotment['I'], errors='coerce')
period_allotment.fillna(0, inplace=True)
period_allotment = period_allotment[period_allotment['Subject'].apply(lambda x: isinstance(x, str) and x.strip() != "0")]

# %%
# Get unique subject names from both DataFrames
period_allotment_subjects = set(period_allotment['Subject'].unique())
teacher_subject_mapping_subjects = set(teacher_subject_mapping['Subject'].unique())

# Find subjects in Period Allotment not in Teacher-Subject Mapping
subjects_not_in_mapping = period_allotment_subjects - teacher_subject_mapping_subjects

# Find subjects in Teacher-Subject Mapping not in Period Allotment
subjects_not_in_allotment = teacher_subject_mapping_subjects - period_allotment_subjects

# Display mismatches
if subjects_not_in_mapping or subjects_not_in_allotment:
    print("Subjects in Period Allotment not in Teacher-Subject Mapping:")
    print(subjects_not_in_mapping if subjects_not_in_mapping else "None")

    print("\nSubjects in Teacher-Subject Mapping not in Period Allotment:")
    print(subjects_not_in_allotment if subjects_not_in_allotment else "None")
else:
    print("All subject names are in sync between Period Allotment and Teacher-Subject Mapping.")
# Out:
# Subjects in Period Allotment not in Teacher-Subject Mapping:
# {'Yoga', 'PLAY PEN ', 'Role play', 'Marathi ', 'PE/ CCA Sports', 'Mathematic ', 'Music T', 'CCA-CREATIVE', 'Environmental Education --EE', 'KARATE ', 'CLASS TESTS ', 'Life Skill', 'SGI'}
#
# Subjects in Teacher-Subject Mapping not in Period Allotment:
# {'Economics ', 'State Level Marathi ', nan, 'Applied Math ', 'SUPW', 'POL SCIENCE ', 'PHYSICS', 'Legal Studies ', 'Marathi -3rd Lang', 'GEOG ', 'Enterpreneurship', 'Mathematics', 'FM', 'HIST ', 'Sanskrit ', 'AI', 'Accountancy', 'Environmental Education', 'Mass Media ', 'Buisness Studies ', 'KARATE', 'YOGA', 'ESL ', 'BIO', 'Life skills ', 'PSYCHOLOGY ', 'SPANISH', 'CHEM', 'General studies ', 'Commercial  Art', 'SAP/ Career Counselling ', 'Physical EDUCATION', 'CIVICS', 'Computer Science'}

# %%
# Step 4: Preprocess the data
period_allotment = period_allotment.fillna(0)

# %%
# Step 5: Define key constraints
PERIODS_PER_DAY = 10
DAYS_PER_WEEK = 5
PERIOD_DURATION = 30

columns = ['1st', '2nd','3rd', '4th','5th','break', '6th', '7th','dispersal']
rows = ['mon', 'tue', 'wed', 'thu', 'fri']
columns1 = ['HomeRoom', '1st', '2nd','break', '3rd', '4th','5th', '6th', '7th','8th','break','9th','10th','dispersal']

# %%
# Step 6: Create a blank timetable structure
def initialize_timetable(classes, sections):
    timetable = {}
    for cls in classes:
        timetable[cls] = {}
        for section in sections:
            if cls in ['Jr. KG', 'Sr. KG']:
                timetable[cls][section] = pd.DataFrame(' ', index=rows, columns=columns)
            elif cls == 'I':
                timetable[cls][section] = pd.DataFrame(' ', index=rows, columns=columns1)
    return timetable

def fill_common_columns(timetable):
    common_columns = {
        'break': 'Break',
        'dispersal': 'Dispersal',
        'HomeRoom': 'HomeRoom'
    }
    for cls, sections in timetable.items():
        for section, df in sections.items():
            for column, value in common_columns.items():
                if column in df.columns:
                    df[column] = value

    return timetable

# Define the fixed assembly schedule
def add_assembly(timetable):
    assembly_schedule = {
        'Jr. KG': {'day': 'tue', 'period': '2nd'},
        'Sr. KG': {'day': 'tue', 'period': '2nd'},
        'I': {'day': 'tue', 'period': '5th'}
    }
    for cls, sections in timetable.items():
        if cls in assembly_schedule:
            assembly_day = assembly_schedule[cls]['day']
            assembly_period = assembly_schedule[cls]['period']
            for section, df in sections.items():
                if assembly_day in df.index and assembly_period in df.columns:
                    df.loc[assembly_day, assembly_period] = 'Assembly'
    return timetable

# %%
classes = ['Jr. KG', 'Sr. KG', 'I']
sections = ['A', 'B', 'C', 'D']
timetable = initialize_timetable(classes, sections)

# %%
def allocate_subjects(timetable, period_allotment):
    period_allotment = {subject: freq for subject, freq in period_allotment.items() if subject != 'Assembly' and freq != 0.5}
    for subject, frequency in period_allotment.items():
        periods_allocated = 0
        for slot in timetable.columns:
            if slot in ['break', 'dispersal', 'HomeRoom']:
                continue
            for day in timetable.index:
                if periods_allocated >= frequency:
                    break
                if timetable.at[day, slot].strip() == '':
                    timetable.at[day, slot] = subject
                    periods_allocated += 1
                if periods_allocated >= frequency:
                    break
            if periods_allocated >= frequency:
                break
    return timetable

# %%
def assign_teachers(timetable, teacher_subject_mapping):
    for cls in classes:
        for section in sections:
            class_section = f"{cls}{' ' if cls != 'I' else ''}{section}"
            if class_section not in teacher_subject_mapping.columns:
                print(f"Class-Section {class_section} not found in teacher_subject_mapping.")
                continue
            for day in rows:
                for col in columns:
                    if col not in ['break', 'dispersal', 'HomeRoom']:
                        subject = timetable[cls][section].loc[day, col]
                        if subject != '':
                            # print("in")
                            teachers = teacher_subject_mapping.loc[
                                teacher_subject_mapping['Subject'] == subject,
                                class_section
                            ].values
                            if teachers.size > 0:
                                timetable[cls][section].loc[day, col] += f" ({teachers[0]})"

# %%
def pair_half_frequency_subjects(period_allotment):
    paired_subjects = {}
    for cls in ['Jr. KG', 'Sr. KG', 'I']:
        half_freq_subjects = period_allotment[['Subject', cls]]
        subjects = half_freq_subjects[half_freq_subjects[cls] == 0.5]['Subject'].dropna().tolist()
        paired_subjects[cls] = [
            (subjects[i], subjects[i+1])
            for i in range(0, len(subjects) - 1, 2)
        ]
        if len(subjects) % 2 == 1:
            paired_subjects[cls].append((subjects[-1], subjects[-1]))
    return paired_subjects
paired_subjects = pair_half_frequency_subjects(period_allotment)
print(paired_subjects)

def allocate_combined_half_frequency_subjects(timetable, paired_subjects):
    for cls, pairs in paired_subjects.items():
        combined_pairs = [f"{pair[0]} / {pair[1]}" for pair in pairs]
        print(f"Processing class: {cls}")
        print(f"Combined pairs for {cls}: {combined_pairs}")
        for section, days in timetable[cls].items():
            print(f"Processing {cls} - {section}: {days}")
            allocated_pairs = set()
            for day, periods in days.items():
                if day in ['break', 'dispersal']:
                    print(f"Skipping {day} for {cls} as it is not a class day.")
                    continue
                print(f"Processing day: {day}")
                empty_slots = [i for i, period in enumerate(periods) if period.strip() == '']
                print(f"Empty slots for {cls} on {day}: {empty_slots}")
                if not empty_slots:
                    print(f"No empty slots for {cls} on {day}, skipping.")
                    continue
                for pair in combined_pairs:
                    if pair not in allocated_pairs and empty_slots:
                        periods[empty_slots[0]] = pair
                        print(f"Allocated '{pair}' to {cls} on {day}, slot {empty_slots[0]}")
                        allocated_pairs.add(pair)
                        empty_slots.pop(0)
                        if len(allocated_pairs) == len(combined_pairs):
                            print(f"All pairs allocated for {cls} on {day}")
                            break
                for i in empty_slots:
                    periods[i] = "leisure"

    return timetable
# Out:
# {'Jr. KG': [('Computer Studies', 'Circle Time'), ('Life Skill', 'Yoga'), ('PLAY PEN ', 'Role play')], 'Sr. KG': [('Computer Studies', 'Circle Time'), ('Life Skill', 'Yoga'), ('DEED', 'Assembly'), ('PLAY PEN ', 'PLAY PEN ')], 'I': []}

# %%
add_assembly(timetable)
for cls in classes:
    for section in sections:
        if cls in period_allotment.columns:
            period_allotment_class = period_allotment[['Subject', cls]]
            period_allotment_class = period_allotment_class.set_index('Subject').to_dict()[cls]
            timetable[cls][section] = allocate_subjects(timetable[cls][section], ) period_allotment_class
        else:
            print(f"Class {cls} not found in period_allotment columns")
timetable = allocate_combined_half_frequency_subjects(timetable, paired_subjects)
assign_teachers(timetable, teacher_subject_mapping)
fill_common_columns(timetable)
# Out:
# Processing class: Jr. KG
# Combined pairs for Jr. KG: ['Computer Studies / Circle Time', 'Life Skill / Yoga', 'PLAY PEN  / Role play']
# Processing Jr. KG - A:      1st       2nd          3rd             4th             5th break  \
# mon  Eng     Hindi  Mathematic              EVS  Clay modelling
# tue  Eng  Assembly  Mathematic   PE/ CCA Sports           Music
# wed  Eng     Hindi  Mathematic   PE/ CCA Sports           Dance
# thu  Eng     Hindi  Mathematic             Art          Library
# fri  Eng     Hindi          EVS            Art             DEED
#
#                               6th 7th dispersal
# mon                   Wonder time
# tue  Environmental Education --EE
# wed  Environmental Education --EE
# thu
# fri
# Processing day: 1st
# Empty slots for Jr. KG on 1st: []
# No empty slots for Jr. KG on 1st, skipping.
# Processing day: 2nd
# Empty slots for Jr. KG on 2nd: []
# No empty slots for Jr. KG on 2nd, skipping.
# Processing day: 3rd
# Empty slots for Jr. KG on 3rd: []
# No empty slots for Jr. KG on 3rd, skipping.
# Processing day: 4th
# Empty slots for Jr. KG on 4th: []
# No empty slots for Jr. KG on 4th, skipping.
# Processing day: 5th
# Empty slots for Jr. KG on 5th: []
# No empty slots for Jr. KG on 5th, skipping.
# Skipping break for Jr. KG as it is not a class day.
# Processing day: 6th
# Empty slots for Jr. KG on 6th: [3, 4]
# Allocated 'Computer Studies / Circle Time' to Jr. KG on 6th, slot 3
# Allocated 'Life Skill / Yoga' to Jr. KG on 6th, slot 4
# Processing day: 7th
# Empty slots for Jr. KG on 7th: [0, 1, 2, 3, 4]
# Allocated 'PLAY PEN  / Role play' to Jr. KG on 7th, slot 0
# All pairs allocated for Jr. KG on 7th
# Skipping dispersal for Jr. KG as it is not a class day.
# Processing Jr. KG - B:      1st       2nd          3rd             4th             5th break  \
# mon  Eng     Hindi  Mathematic              EVS  Clay modelling
# tue  Eng  Assembly  Mathematic   PE/ CCA Sports           Music
# wed  Eng     Hindi  Mathematic   PE/ CCA Sports           Dance
# thu  Eng     Hindi  Mathematic             Art          Library
# fri  Eng     Hindi          EVS            Art             DEED
#
#                               6th 7th dispersal
# mon                   Wonder time
# tue  Environmental Education --EE
# wed  Environmental Education --EE
# thu
# fri
# Processing day: 1st
# Empty slots for Jr. KG on 1st: []
# No empty slots for Jr. KG on 1st, skipping.
# Processing day: 2nd
# Empty slots for Jr. KG on 2nd: []
# No empty slots for Jr. KG on 2nd, skipping.
# Processing day: 3rd
# Empty slots for Jr. KG on 3rd: []
# No empty slots for Jr. KG on 3rd, skipping.
# Processing day: 4th
# Empty slots for Jr. KG on 4th: []
# No empty slots for Jr. KG on 4th, skipping.
# Processing day: 5th
# Empty slots for Jr. KG on 5th: []
# No empty slots for Jr. KG on 5th, skipping.
# Skipping break for Jr. KG as it is not a class day.
# Processing day: 6th
# Empty slots for Jr. KG on 6th: [3, 4]
# Allocated 'Computer Studies / Circle Time' to Jr. KG on 6th, slot 3
# Allocated 'Life Skill / Yoga' to Jr. KG on 6th, slot 4
# Processing day: 7th
# Empty slots for Jr. KG on 7th: [0, 1, 2, 3, 4]
# Allocated 'PLAY PEN  / Role play' to Jr. KG on 7th, slot 0
# All pairs allocated for Jr. KG on 7th
# Skipping dispersal for Jr. KG as it is not a class day.
# Processing Jr. KG - C:      1st       2nd          3rd             4th             5th break  \
# mon  Eng     Hindi  Mathematic              EVS  Clay modelling
# tue  Eng  Assembly  Mathematic   PE/ CCA Sports           Music
# wed  Eng     Hindi  Mathematic   PE/ CCA Sports           Dance
# thu  Eng     Hindi  Mathematic             Art          Library
# fri  Eng     Hindi          EVS            Art             DEED
#
#                               6th 7th dispersal
# mon                   Wonder time
# tue  Environmental Education --EE
# wed  Environmental Education --EE
# thu
# fri
# Processing day: 1st
# Empty slots for Jr. KG on 1st: []
# No empty slots for Jr. KG on 1st, skipping.
# Processing day: 2nd
# Empty slots for Jr. KG on 2nd: []
# No empty slots for Jr. KG on 2nd, skipping.
# Processing day: 3rd
# Empty slots for Jr. KG on 3rd: []
# No empty slots for Jr. KG on 3rd, skipping.
# Processing day: 4th
# Empty slots for Jr. KG on 4th: []
# No empty slots for Jr. KG on 4th, skipping.
# Processing day: 5th
# Empty slots for Jr. KG on 5th: []
# No empty slots for Jr. KG on 5th, skipping.
# Skipping break for Jr. KG as it is not a class day.
# Processing day: 6th
# Empty slots for Jr. KG on 6th: [3, 4]
# Allocated 'Computer Studies / Circle Time' to Jr. KG on 6th, slot 3
# Allocated 'Life Skill / Yoga' to Jr. KG on 6th, slot 4
# Processing day: 7th
# Empty slots for Jr. KG on 7th: [0, 1, 2, 3, 4]
# Allocated 'PLAY PEN  / Role play' to Jr. KG on 7th, slot 0
# All pairs allocated for Jr. KG on 7th
# Skipping dispersal for Jr. KG as it is not a class day.
# Processing Jr. KG - D:      1st       2nd          3rd             4th             5th break  \
# mon  Eng     Hindi  Mathematic              EVS  Clay modelling
# tue  Eng  Assembly  Mathematic   PE/ CCA Sports           Music
# wed  Eng     Hindi  Mathematic   PE/ CCA Sports           Dance
# thu  Eng     Hindi  Mathematic             Art          Library
# fri  Eng     Hindi          EVS            Art             DEED
#
#                               6th 7th dispersal
# mon                   Wonder time
# tue  Environmental Education --EE
# wed  Environmental Education --EE
# thu
# fri
# Processing day: 1st
# Empty slots for Jr. KG on 1st: []
# No empty slots for Jr. KG on 1st, skipping.
# Processing day: 2nd
# Empty slots for Jr. KG on 2nd: []
# No empty slots for Jr. KG on 2nd, skipping.
# Processing day: 3rd
# Empty slots for Jr. KG on 3rd: []
# No empty slots for Jr. KG on 3rd, skipping.
# Processing day: 4th
# Empty slots for Jr. KG on 4th: []
# No empty slots for Jr. KG on 4th, skipping.
# Processing day: 5th
# Empty slots for Jr. KG on 5th: []
# No empty slots for Jr. KG on 5th, skipping.
# Skipping break for Jr. KG as it is not a class day.
# Processing day: 6th
# Empty slots for Jr. KG on 6th: [3, 4]
# Allocated 'Computer Studies / Circle Time' to Jr. KG on 6th, slot 3
# Allocated 'Life Skill / Yoga' to Jr. KG on 6th, slot 4
# Processing day: 7th
# Empty slots for Jr. KG on 7th: [0, 1, 2, 3, 4]
# Allocated 'PLAY PEN  / Role play' to Jr. KG on 7th, slot 0
# All pairs allocated for Jr. KG on 7th
# Skipping dispersal for Jr. KG as it is not a class day.
# Processing class: Sr. KG
# Combined pairs for Sr. KG: ['Computer Studies / Circle Time', 'Life Skill / Yoga', 'DEED / Assembly', 'PLAY PEN  / PLAY PEN ']
# Processing Sr. KG - A:      1st       2nd          3rd             4th             5th break  \
# mon  Eng     Hindi  Mathematic              EVS            Art
# tue  Eng  Assembly  Mathematic              EVS            Art
# wed  Eng     Hindi  Mathematic              EVS  Clay modelling
# thu  Eng     Hindi  Mathematic   PE/ CCA Sports           Music
# fri  Eng     Hindi  Mathematic   PE/ CCA Sports           Dance
#
#                               6th 7th dispersal
# mon                       Library
# tue                   Wonder time
# wed  Environmental Education --EE
# thu
# fri
# Processing day: 1st
# Empty slots for Sr. KG on 1st: []
# No empty slots for Sr. KG on 1st, skipping.
# Processing day: 2nd
# Empty slots for Sr. KG on 2nd: []
# No empty slots for Sr. KG on 2nd, skipping.
# Processing day: 3rd
# Empty slots for Sr. KG on 3rd: []
# No empty slots for Sr. KG on 3rd, skipping.
# Processing day: 4th
# Empty slots for Sr. KG on 4th: []
# No empty slots for Sr. KG on 4th, skipping.
# Processing day: 5th
# Empty slots for Sr. KG on 5th: []
# No empty slots for Sr. KG on 5th, skipping.
# Skipping break for Sr. KG as it is not a class day.
# Processing day: 6th
# Empty slots for Sr. KG on 6th: [3, 4]
# Allocated 'Computer Studies / Circle Time' to Sr. KG on 6th, slot 3
# Allocated 'Life Skill / Yoga' to Sr. KG on 6th, slot 4
# Processing day: 7th
# Empty slots for Sr. KG on 7th: [0, 1, 2, 3, 4]
# Allocated 'DEED / Assembly' to Sr. KG on 7th, slot 0
# Allocated 'PLAY PEN  / PLAY PEN ' to Sr. KG on 7th, slot 1
# All pairs allocated for Sr. KG on 7th
# Skipping dispersal for Sr. KG as it is not a class day.
# Processing Sr. KG - B:      1st       2nd          3rd             4th             5th break  \
# mon  Eng     Hindi  Mathematic              EVS            Art
# tue  Eng  Assembly  Mathematic              EVS            Art
# wed  Eng     Hindi  Mathematic              EVS  Clay modelling
# thu  Eng     Hindi  Mathematic   PE/ CCA Sports           Music
# fri  Eng     Hindi  Mathematic   PE/ CCA Sports           Dance
#
#                               6th 7th dispersal
# mon                       Library
# tue                   Wonder time
# wed  Environmental Education --EE
# thu
# fri
# Processing day: 1st
# Empty slots for Sr. KG on 1st: []
# No empty slots for Sr. KG on 1st, skipping.
# Processing day: 2nd
# Empty slots for Sr. KG on 2nd: []
# No empty slots for Sr. KG on 2nd, skipping.
# Processing day: 3rd
# Empty slots for Sr. KG on 3rd: []
# No empty slots for Sr. KG on 3rd, skipping.
# Processing day: 4th
# Empty slots for Sr. KG on 4th: []
# No empty slots for Sr. KG on 4th, skipping.
# Processing day: 5th
# Empty slots for Sr. KG on 5th: []
# No empty slots for Sr. KG on 5th, skipping.
# Skipping break for Sr. KG as it is not a class day.
# Processing day: 6th
# Empty slots for Sr. KG on 6th: [3, 4]
# Allocated 'Computer Studies / Circle Time' to Sr. KG on 6th, slot 3
# Allocated 'Life Skill / Yoga' to Sr. KG on 6th, slot 4
# Processing day: 7th
# Empty slots for Sr. KG on 7th: [0, 1, 2, 3, 4]
# Allocated 'DEED / Assembly' to Sr. KG on 7th, slot 0
# Allocated 'PLAY PEN  / PLAY PEN ' to Sr. KG on 7th, slot 1
# All pairs allocated for Sr. KG on 7th
# Skipping dispersal for Sr. KG as it is not a class day.
# Processing Sr. KG - C:      1st       2nd          3rd             4th             5th break  \
# mon  Eng     Hindi  Mathematic              EVS            Art
# tue  Eng  Assembly  Mathematic              EVS            Art
# wed  Eng     Hindi  Mathematic              EVS  Clay modelling
# thu  Eng     Hindi  Mathematic   PE/ CCA Sports           Music
# fri  Eng     Hindi  Mathematic   PE/ CCA Sports           Dance
#
#                               6th 7th dispersal
# mon                       Library
# tue                   Wonder time
# wed  Environmental Education --EE
# thu
# fri
# Processing day: 1st
# Empty slots for Sr. KG on 1st: []
# No empty slots for Sr. KG on 1st, skipping.
# Processing day: 2nd
# Empty slots for Sr. KG on 2nd: []
# No empty slots for Sr. KG on 2nd, skipping.
# Processing day: 3rd
# Empty slots for Sr. KG on 3rd: []
# No empty slots for Sr. KG on 3rd, skipping.
# Processing day: 4th
# Empty slots for Sr. KG on 4th: []
# No empty slots for Sr. KG on 4th, skipping.
# Processing day: 5th
# Empty slots for Sr. KG on 5th: []
# No empty slots for Sr. KG on 5th, skipping.
# Skipping break for Sr. KG as it is not a class day.
# Processing day: 6th
# Empty slots for Sr. KG on 6th: [3, 4]
# Allocated 'Computer Studies / Circle Time' to Sr. KG on 6th, slot 3
# Allocated 'Life Skill / Yoga' to Sr. KG on 6th, slot 4
# Processing day: 7th
# Empty slots for Sr. KG on 7th: [0, 1, 2, 3, 4]
# Allocated 'DEED / Assembly' to Sr. KG on 7th, slot 0
# Allocated 'PLAY PEN  / PLAY PEN ' to Sr. KG on 7th, slot 1
# All pairs allocated for Sr. KG on 7th
# Skipping dispersal for Sr. KG as it is not a class day.
# Processing Sr. KG - D:      1st       2nd          3rd             4th             5th break  \
# mon  Eng     Hindi  Mathematic              EVS            Art
# tue  Eng  Assembly  Mathematic              EVS            Art
# wed  Eng     Hindi  Mathematic              EVS  Clay modelling
# thu  Eng     Hindi  Mathematic   PE/ CCA Sports           Music
# fri  Eng     Hindi  Mathematic   PE/ CCA Sports           Dance
#
#                               6th 7th dispersal
# mon                       Library
# tue                   Wonder time
# wed  Environmental Education --EE
# thu
# fri
# Processing day: 1st
# Empty slots for Sr. KG on 1st: []
# No empty slots for Sr. KG on 1st, skipping.
# Processing day: 2nd
# Empty slots for Sr. KG on 2nd: []
# No empty slots for Sr. KG on 2nd, skipping.
# Processing day: 3rd
# Empty slots for Sr. KG on 3rd: []
# No empty slots for Sr. KG on 3rd, skipping.
# Processing day: 4th
# Empty slots for Sr. KG on 4th: []
# No empty slots for Sr. KG on 4th, skipping.
# Processing day: 5th
# Empty slots for Sr. KG on 5th: []
# No empty slots for Sr. KG on 5th, skipping.
# Skipping break for Sr. KG as it is not a class day.
# Processing day: 6th
# Empty slots for Sr. KG on 6th: [3, 4]
# Allocated 'Computer Studies / Circle Time' to Sr. KG on 6th, slot 3
# Allocated 'Life Skill / Yoga' to Sr. KG on 6th, slot 4
# Processing day: 7th
# Empty slots for Sr. KG on 7th: [0, 1, 2, 3, 4]
# Allocated 'DEED / Assembly' to Sr. KG on 7th, slot 0
# Allocated 'PLAY PEN  / PLAY PEN ' to Sr. KG on 7th, slot 1
# All pairs allocated for Sr. KG on 7th
# Skipping dispersal for Sr. KG as it is not a class day.
# Processing class: I
# Combined pairs for I: []
# Processing I - A:     HomeRoom  1st    2nd break          3rd          4th          5th  \
# mon           Eng    Eng              Hindi  Mathematic   Mathematic
# tue           Eng    Eng              Hindi  Mathematic      Assembly
# wed           Eng    Eng              Hindi  Mathematic      Marathi
# thu           Eng  Hindi              Hindi  Mathematic      Marathi
# fri           Eng  Hindi        Mathematic   Mathematic           EVS
#
#                   6th               7th             8th break      9th  \
# mon               EVS  Computer Studies            Yoga          Music
# tue               EVS       Circle Time         KARATE         Music T
# wed               EVS        Life Skill            Art           Dance
# thu               EVS    PE/ CCA Sports            Art         Library
# fri  Computer Studies    PE/ CCA Sports  Clay modelling           DEED
#
#                              10th dispersal
# mon                   Wonder time
# tue  Environmental Education --EE
# wed                           SGI
# thu                           SGI
# fri                  CLASS TESTS
# Processing day: HomeRoom
# Empty slots for I on HomeRoom: [0, 1, 2, 3, 4]
# Processing day: 1st
# Empty slots for I on 1st: []
# No empty slots for I on 1st, skipping.
# Processing day: 2nd
# Empty slots for I on 2nd: []
# No empty slots for I on 2nd, skipping.
# Skipping break for I as it is not a class day.
# Processing day: 3rd
# Empty slots for I on 3rd: []
# No empty slots for I on 3rd, skipping.
# Processing day: 4th
# Empty slots for I on 4th: []
# No empty slots for I on 4th, skipping.
# Processing day: 5th
# Empty slots for I on 5th: []
# No empty slots for I on 5th, skipping.
# Processing day: 6th
# Empty slots for I on 6th: []
# No empty slots for I on 6th, skipping.
# Processing day: 7th
# Empty slots for I on 7th: []
# No empty slots for I on 7th, skipping.
# Processing day: 8th
# Empty slots for I on 8th: []
# No empty slots for I on 8th, skipping.
# Skipping break for I as it is not a class day.
# Processing day: 9th
# Empty slots for I on 9th: []
# No empty slots for I on 9th, skipping.
# Processing day: 10th
# Empty slots for I on 10th: []
# No empty slots for I on 10th, skipping.
# Skipping dispersal for I as it is not a class day.
# Processing I - B:     HomeRoom  1st    2nd break          3rd          4th          5th  \
# mon           Eng    Eng              Hindi  Mathematic   Mathematic
# tue           Eng    Eng              Hindi  Mathematic      Assembly
# wed           Eng    Eng              Hindi  Mathematic      Marathi
# thu           Eng  Hindi              Hindi  Mathematic      Marathi
# fri           Eng  Hindi        Mathematic   Mathematic           EVS
#
#                   6th               7th             8th break      9th  \
# mon               EVS  Computer Studies            Yoga          Music
# tue               EVS       Circle Time         KARATE         Music T
# wed               EVS        Life Skill            Art           Dance
# thu               EVS    PE/ CCA Sports            Art         Library
# fri  Computer Studies    PE/ CCA Sports  Clay modelling           DEED
#
#                              10th dispersal
# mon                   Wonder time
# tue  Environmental Education --EE
# wed                           SGI
# thu                           SGI
# fri                  CLASS TESTS
# Processing day: HomeRoom
# Empty slots for I on HomeRoom: [0, 1, 2, 3, 4]
# Processing day: 1st
# Empty slots for I on 1st: []
# No empty slots for I on 1st, skipping.
# Processing day: 2nd
# Empty slots for I on 2nd: []
# No empty slots for I on 2nd, skipping.
# Skipping break for I as it is not a class day.
# Processing day: 3rd
# Empty slots for I on 3rd: []
# No empty slots for I on 3rd, skipping.
# Processing day: 4th
# Empty slots for I on 4th: []
# No empty slots for I on 4th, skipping.
# Processing day: 5th
# Empty slots for I on 5th: []
# No empty slots for I on 5th, skipping.
# Processing day: 6th
# Empty slots for I on 6th: []
# No empty slots for I on 6th, skipping.
# Processing day: 7th
# Empty slots for I on 7th: []
# No empty slots for I on 7th, skipping.
# Processing day: 8th
# Empty slots for I on 8th: []
# No empty slots for I on 8th, skipping.
# Skipping break for I as it is not a class day.
# Processing day: 9th
# Empty slots for I on 9th: []
# No empty slots for I on 9th, skipping.
# Processing day: 10th
# Empty slots for I on 10th: []
# No empty slots for I on 10th, skipping.
# Skipping dispersal for I as it is not a class day.
# Processing I - C:     HomeRoom  1st    2nd break          3rd          4th          5th  \
# mon           Eng    Eng              Hindi  Mathematic   Mathematic
# tue           Eng    Eng              Hindi  Mathematic      Assembly
# wed           Eng    Eng              Hindi  Mathematic      Marathi
# thu           Eng  Hindi              Hindi  Mathematic      Marathi
# fri           Eng  Hindi        Mathematic   Mathematic           EVS
#
#                   6th               7th             8th break      9th  \
# mon               EVS  Computer Studies            Yoga          Music
# tue               EVS       Circle Time         KARATE         Music T
# wed               EVS        Life Skill            Art           Dance
# thu               EVS    PE/ CCA Sports            Art         Library
# fri  Computer Studies    PE/ CCA Sports  Clay modelling           DEED
#
#                              10th dispersal
# mon                   Wonder time
# tue  Environmental Education --EE
# wed                           SGI
# thu                           SGI
# fri                  CLASS TESTS
# Processing day: HomeRoom
# Empty slots for I on HomeRoom: [0, 1, 2, 3, 4]
# Processing day: 1st
# Empty slots for I on 1st: []
# No empty slots for I on 1st, skipping.
# Processing day: 2nd
# Empty slots for I on 2nd: []
# No empty slots for I on 2nd, skipping.
# Skipping break for I as it is not a class day.
# Processing day: 3rd
# Empty slots for I on 3rd: []
# No empty slots for I on 3rd, skipping.
# Processing day: 4th
# Empty slots for I on 4th: []
# No empty slots for I on 4th, skipping.
# Processing day: 5th
# Empty slots for I on 5th: []
# No empty slots for I on 5th, skipping.
# Processing day: 6th
# Empty slots for I on 6th: []
# No empty slots for I on 6th, skipping.
# Processing day: 7th
# Empty slots for I on 7th: []
# No empty slots for I on 7th, skipping.
# Processing day: 8th
# Empty slots for I on 8th: []
# No empty slots for I on 8th, skipping.
# Skipping break for I as it is not a class day.
# Processing day: 9th
# Empty slots for I on 9th: []
# No empty slots for I on 9th, skipping.
# Processing day: 10th
# Empty slots for I on 10th: []
# No empty slots for I on 10th, skipping.
# Skipping dispersal for I as it is not a class day.
# Processing I - D:     HomeRoom  1st    2nd break          3rd          4th          5th  \
# mon           Eng    Eng              Hindi  Mathematic   Mathematic
# tue           Eng    Eng              Hindi  Mathematic      Assembly
# wed           Eng    Eng              Hindi  Mathematic      Marathi
# thu           Eng  Hindi              Hindi  Mathematic      Marathi
# fri           Eng  Hindi        Mathematic   Mathematic           EVS
#
#                   6th               7th             8th break      9th  \
# mon               EVS  Computer Studies            Yoga          Music
# tue               EVS       Circle Time         KARATE         Music T
# wed               EVS        Life Skill            Art           Dance
# thu               EVS    PE/ CCA Sports            Art         Library
# fri  Computer Studies    PE/ CCA Sports  Clay modelling           DEED
#
#                              10th dispersal
# mon                   Wonder time
# tue  Environmental Education --EE
# wed                           SGI
# thu                           SGI
# fri                  CLASS TESTS
# Processing day: HomeRoom
# Empty slots for I on HomeRoom: [0, 1, 2, 3, 4]
# Processing day: 1st
# Empty slots for I on 1st: []
# No empty slots for I on 1st, skipping.
# Processing day: 2nd
# Empty slots for I on 2nd: []
# No empty slots for I on 2nd, skipping.
# Skipping break for I as it is not a class day.
# Processing day: 3rd
# Empty slots for I on 3rd: []
# No empty slots for I on 3rd, skipping.
# Processing day: 4th
# Empty slots for I on 4th: []
# No empty slots for I on 4th, skipping.
# Processing day: 5th
# Empty slots for I on 5th: []
# No empty slots for I on 5th, skipping.
# Processing day: 6th
# Empty slots for I on 6th: []
# No empty slots for I on 6th, skipping.
# Processing day: 7th
# Empty slots for I on 7th: []
# No empty slots for I on 7th, skipping.
# Processing day: 8th
# Empty slots for I on 8th: []
# No empty slots for I on 8th, skipping.
# Skipping break for I as it is not a class day.
# Processing day: 9th
# Empty slots for I on 9th: []
# No empty slots for I on 9th, skipping.
# Processing day: 10th
# Empty slots for I on 10th: []
# No empty slots for I on 10th, skipping.
# Skipping dispersal for I as it is not a class day.
# <ipython-input-94-da2118e2a8c7>:36: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[empty_slots[0]] = pair
# <ipython-input-94-da2118e2a8c7>:36: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[empty_slots[0]] = pair
# <ipython-input-94-da2118e2a8c7>:36: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[empty_slots[0]] = pair
# <ipython-input-94-da2118e2a8c7>:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-94-da2118e2a8c7>:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-94-da2118e2a8c7>:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-94-da2118e2a8c7>:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-94-da2118e2a8c7>:36: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[empty_slots[0]] = pair
# <ipython-input-94-da2118e2a8c7>:36: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[empty_slots[0]] = pair
# <ipython-input-94-da2118e2a8c7>:36: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[empty_slots[0]] = pair
# <ipython-input-94-da2118e2a8c7>:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-94-da2118e2a8c7>:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-94-da2118e2a8c7>:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-94-da2118e2a8c7>:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-94-da2118e2a8c7>:36: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[empty_slots[0]] = pair
# <ipython-input-94-da2118e2a8c7>:36: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[empty_slots[0]] = pair
# <ipython-input-94-da2118e2a8c7>:36: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[empty_slots[0]] = pair
# <ipython-input-94-da2118e2a8c7>:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-94-da2118e2a8c7>:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-94-da2118e2a8c7>:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-94-da2118e2a8c7>:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-94-da2118e2a8c7>:36: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[empty_slots[0]] = pair
# <ipython-input-94-da2118e2a8c7>:36: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[empty_slots[0]] = pair
# <ipython-input-94-da2118e2a8c7>:36: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[empty_slots[0]] = pair
# <ipython-input-94-da2118e2a8c7>:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-94-da2118e2a8c7>:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-94-da2118e2a8c7>:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-94-da2118e2a8c7>:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-94-da2118e2a8c7>:36: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[empty_slots[0]] = pair
# <ipython-input-94-da2118e2a8c7>:36: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[empty_slots[0]] = pair
# <ipython-input-94-da2118e2a8c7>:36: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[empty_slots[0]] = pair
# <ipython-input-94-da2118e2a8c7>:36: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[empty_slots[0]] = pair
# <ipython-input-94-da2118e2a8c7>:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-94-da2118e2a8c7>:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-94-da2118e2a8c7>:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-94-da2118e2a8c7>:36: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[empty_slots[0]] = pair
# <ipython-input-94-da2118e2a8c7>:36: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[empty_slots[0]] = pair
# <ipython-input-94-da2118e2a8c7>:36: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[empty_slots[0]] = pair
# <ipython-input-94-da2118e2a8c7>:36: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[empty_slots[0]] = pair
# <ipython-input-94-da2118e2a8c7>:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-94-da2118e2a8c7>:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-94-da2118e2a8c7>:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-94-da2118e2a8c7>:36: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[empty_slots[0]] = pair
# <ipython-input-94-da2118e2a8c7>:36: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[empty_slots[0]] = pair
# <ipython-input-94-da2118e2a8c7>:36: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[empty_slots[0]] = pair
# <ipython-input-94-da2118e2a8c7>:36: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[empty_slots[0]] = pair
# <ipython-input-94-da2118e2a8c7>:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-94-da2118e2a8c7>:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-94-da2118e2a8c7>:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-94-da2118e2a8c7>:36: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[empty_slots[0]] = pair
# <ipython-input-94-da2118e2a8c7>:36: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[empty_slots[0]] = pair
# <ipython-input-94-da2118e2a8c7>:36: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[empty_slots[0]] = pair
# <ipython-input-94-da2118e2a8c7>:36: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[empty_slots[0]] = pair
# <ipython-input-94-da2118e2a8c7>:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-94-da2118e2a8c7>:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-94-da2118e2a8c7>:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-94-da2118e2a8c7>:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-94-da2118e2a8c7>:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-94-da2118e2a8c7>:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-94-da2118e2a8c7>:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-94-da2118e2a8c7>:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-94-da2118e2a8c7>:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-94-da2118e2a8c7>:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-94-da2118e2a8c7>:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-94-da2118e2a8c7>:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-94-da2118e2a8c7>:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-94-da2118e2a8c7>:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-94-da2118e2a8c7>:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-94-da2118e2a8c7>:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-94-da2118e2a8c7>:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-94-da2118e2a8c7>:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-94-da2118e2a8c7>:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-94-da2118e2a8c7>:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-94-da2118e2a8c7>:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-94-da2118e2a8c7>:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-94-da2118e2a8c7>:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# {'Jr. KG': {'A':                             1st             2nd          3rd             4th  \
#   mon  Eng (Nupur FT , Pooja  R )      Hindi (HR)  Mathematic         EVS (HR)
#   tue  Eng (Nupur FT , Pooja  R )  Assembly (nan)  Mathematic   PE/ CCA Sports
#   wed  Eng (Nupur FT , Pooja  R )      Hindi (HR)  Mathematic   PE/ CCA Sports
#   thu  Eng (Nupur FT , Pooja  R )      Hindi (HR)  Mathematic        Art  (HR)
#   fri  Eng (Nupur FT , Pooja  R )      Hindi (HR)     EVS (HR)       Art  (HR)
#
#                              5th  break                             6th  \
#   mon  Clay modelling (Shridevi)  Break         Wonder time (Neesha.R )
#   tue           Music (Sanjukta)  Break    Environmental Education --EE
#   wed            Dance (Pooja B)  Break    Environmental Education --EE
#   thu          Library (Pooja S)  Break  Computer Studies / Circle Time
#   fri                DEED (Isha)  Break               Life Skill / Yoga
#
#                          7th  dispersal
#   mon  PLAY PEN  / Role play  Dispersal
#   tue                leisure  Dispersal
#   wed                leisure  Dispersal
#   thu                leisure  Dispersal
#   fri                leisure  Dispersal  ,
#   'B':                     1st             2nd          3rd             4th  \
#   mon  Eng (Maria , Banu)      Hindi (HR)  Mathematic         EVS (HR)
#   tue  Eng (Maria , Banu)  Assembly (nan)  Mathematic   PE/ CCA Sports
#   wed  Eng (Maria , Banu)      Hindi (HR)  Mathematic   PE/ CCA Sports
#   thu  Eng (Maria , Banu)      Hindi (HR)  Mathematic        Art  (HR)
#   fri  Eng (Maria , Banu)      Hindi (HR)     EVS (HR)       Art  (HR)
#
#                              5th  break                             6th  \
#   mon  Clay modelling (Shridevi)  Break         Wonder time (Neesha.R )
#   tue           Music (Sanjukta)  Break    Environmental Education --EE
#   wed            Dance (Pooja B)  Break    Environmental Education --EE
#   thu          Library (Pooja S)  Break  Computer Studies / Circle Time
#   fri                 DEED (nan)  Break               Life Skill / Yoga
#
#                          7th  dispersal
#   mon  PLAY PEN  / Role play  Dispersal
#   tue                leisure  Dispersal
#   wed                leisure  Dispersal
#   thu                leisure  Dispersal
#   fri                leisure  Dispersal  ,
#   'C':                          1st             2nd          3rd             4th  \
#   mon  Eng (Shireen , Riya J )      Hindi (HR)  Mathematic         EVS (HR)
#   tue  Eng (Shireen , Riya J )  Assembly (nan)  Mathematic   PE/ CCA Sports
#   wed  Eng (Shireen , Riya J )      Hindi (HR)  Mathematic   PE/ CCA Sports
#   thu  Eng (Shireen , Riya J )      Hindi (HR)  Mathematic        Art  (HR)
#   fri  Eng (Shireen , Riya J )      Hindi (HR)     EVS (HR)       Art  (HR)
#
#                              5th  break                             6th  \
#   mon  Clay modelling (Shridevi)  Break         Wonder time (Neesha.R )
#   tue             Music (Shlok )  Break    Environmental Education --EE
#   wed            Dance (Pooja B)  Break    Environmental Education --EE
#   thu          Library (Pooja S)  Break  Computer Studies / Circle Time
#   fri                 DEED (nan)  Break               Life Skill / Yoga
#
#                          7th  dispersal
#   mon  PLAY PEN  / Role play  Dispersal
#   tue                leisure  Dispersal
#   wed                leisure  Dispersal
#   thu                leisure  Dispersal
#   fri                leisure  Dispersal  ,
#   'D':                       1st             2nd          3rd             4th  \
#   mon  Eng (Sheetal Anjum )      Hindi (HR)  Mathematic         EVS (HR)
#   tue  Eng (Sheetal Anjum )  Assembly (nan)  Mathematic   PE/ CCA Sports
#   wed  Eng (Sheetal Anjum )      Hindi (HR)  Mathematic   PE/ CCA Sports
#   thu  Eng (Sheetal Anjum )      Hindi (HR)  Mathematic        Art  (HR)
#   fri  Eng (Sheetal Anjum )      Hindi (HR)     EVS (HR)       Art  (HR)
#
#                              5th  break                             6th  \
#   mon  Clay modelling (Shridevi)  Break         Wonder time (Neesha.R )
#   tue             Music (Shlok )  Break    Environmental Education --EE
#   wed            Dance (Pooja B)  Break    Environmental Education --EE
#   thu          Library (Pooja S)  Break  Computer Studies / Circle Time
#   fri                 DEED (nan)  Break               Life Skill / Yoga
#
#                          7th  dispersal
#   mon  PLAY PEN  / Role play  Dispersal
#   tue                leisure  Dispersal
#   wed                leisure  Dispersal
#   thu                leisure  Dispersal
#   fri                leisure  Dispersal  },
#  'Sr. KG': {'A':                         1st             2nd          3rd             4th  \
#   mon  Eng (Ruksaar Darshana)      Hindi (HR)  Mathematic         EVS (HR)
#   tue  Eng (Ruksaar Darshana)  Assembly (nan)  Mathematic         EVS (HR)
#   wed  Eng (Ruksaar Darshana)      Hindi (HR)  Mathematic         EVS (HR)
#   thu  Eng (Ruksaar Darshana)      Hindi (HR)  Mathematic   PE/ CCA Sports
#   fri  Eng (Ruksaar Darshana)      Hindi (HR)  Mathematic   PE/ CCA Sports
#
#                              5th  break                             6th  \
#   mon                  Art  (HR)  Break               Library (Pooja S)
#   tue                  Art  (HR)  Break         Wonder time (Neesha.R )
#   wed  Clay modelling (Shridevi)  Break    Environmental Education --EE
#   thu           Music (Sanjukta)  Break  Computer Studies / Circle Time
#   fri            Dance (Pooja B)  Break               Life Skill / Yoga
#
#                          7th  dispersal
#   mon        DEED / Assembly  Dispersal
#   tue  PLAY PEN  / PLAY PEN   Dispersal
#   wed                leisure  Dispersal
#   thu                leisure  Dispersal
#   fri                leisure  Dispersal  ,
#   'B':                          1st             2nd          3rd             4th  \
#   mon  Eng (Bhakti Laxmipriya)      Hindi (HR)  Mathematic         EVS (HR)
#   tue  Eng (Bhakti Laxmipriya)  Assembly (nan)  Mathematic         EVS (HR)
#   wed  Eng (Bhakti Laxmipriya)      Hindi (HR)  Mathematic         EVS (HR)
#   thu  Eng (Bhakti Laxmipriya)      Hindi (HR)  Mathematic   PE/ CCA Sports
#   fri  Eng (Bhakti Laxmipriya)      Hindi (HR)  Mathematic   PE/ CCA Sports
#
#                              5th  break                             6th  \
#   mon                  Art  (HR)  Break               Library (Pooja S)
#   tue                  Art  (HR)  Break         Wonder time (Neesha.R )
#   wed  Clay modelling (Shridevi)  Break    Environmental Education --EE
#   thu           Music (Sanjukta)  Break  Computer Studies / Circle Time
#   fri            Dance (Pooja B)  Break               Life Skill / Yoga
#
#                          7th  dispersal
#   mon        DEED / Assembly  Dispersal
#   tue  PLAY PEN  / PLAY PEN   Dispersal
#   wed                leisure  Dispersal
#   thu                leisure  Dispersal
#   fri                leisure  Dispersal  ,
#   'C':                              1st             2nd          3rd             4th  \
#   mon  Eng ( Shubha FT , Priyanka)      Hindi (HR)  Mathematic         EVS (HR)
#   tue  Eng ( Shubha FT , Priyanka)  Assembly (nan)  Mathematic         EVS (HR)
#   wed  Eng ( Shubha FT , Priyanka)      Hindi (HR)  Mathematic         EVS (HR)
#   thu  Eng ( Shubha FT , Priyanka)      Hindi (HR)  Mathematic   PE/ CCA Sports
#   fri  Eng ( Shubha FT , Priyanka)      Hindi (HR)  Mathematic   PE/ CCA Sports
#
#                              5th  break                             6th  \
#   mon                  Art  (HR)  Break               Library (Pooja S)
#   tue                  Art  (HR)  Break         Wonder time (Neesha.R )
#   wed  Clay modelling (Shridevi)  Break    Environmental Education --EE
#   thu             Music (Shlok )  Break  Computer Studies / Circle Time
#   fri            Dance (Pooja B)  Break               Life Skill / Yoga
#
#                          7th  dispersal
#   mon        DEED / Assembly  Dispersal
#   tue  PLAY PEN  / PLAY PEN   Dispersal
#   wed                leisure  Dispersal
#   thu                leisure  Dispersal
#   fri                leisure  Dispersal  ,
#   'D':                          1st             2nd          3rd             4th  \
#   mon  Eng (Ankita\n Jyoti V )      Hindi (HR)  Mathematic         EVS (HR)
#   tue  Eng (Ankita\n Jyoti V )  Assembly (nan)  Mathematic         EVS (HR)
#   wed  Eng (Ankita\n Jyoti V )      Hindi (HR)  Mathematic         EVS (HR)
#   thu  Eng (Ankita\n Jyoti V )      Hindi (HR)  Mathematic   PE/ CCA Sports
#   fri  Eng (Ankita\n Jyoti V )      Hindi (HR)  Mathematic   PE/ CCA Sports
#
#                              5th  break                             6th  \
#   mon                  Art  (HR)  Break               Library (Pooja S)
#   tue                  Art  (HR)  Break         Wonder time (Neesha.R )
#   wed  Clay modelling (Shridevi)  Break    Environmental Education --EE
#   thu             Music (Shlok )  Break  Computer Studies / Circle Time
#   fri            Dance (Pooja B)  Break               Life Skill / Yoga
#
#                          7th  dispersal
#   mon        DEED / Assembly  Dispersal
#   tue  PLAY PEN  / PLAY PEN   Dispersal
#   wed                leisure  Dispersal
#   thu                leisure  Dispersal
#   fri                leisure  Dispersal  },
#  'I': {'A':      HomeRoom                        1st                        2nd  break  \
#   mon  HomeRoom  Eng (Remya,Saraswati -FT)  Eng (Remya,Saraswati -FT)  Break
#   tue  HomeRoom  Eng (Remya,Saraswati -FT)  Eng (Remya,Saraswati -FT)  Break
#   wed  HomeRoom  Eng (Remya,Saraswati -FT)  Eng (Remya,Saraswati -FT)  Break
#   thu  HomeRoom  Eng (Remya,Saraswati -FT)             Hindi (Reshma)  Break
#   fri  HomeRoom  Eng (Remya,Saraswati -FT)             Hindi (Reshma)  Break
#
#                   3rd          4th             5th                        6th  \
#   mon  Hindi (Reshma)  Mathematic      Mathematic                    EVS (HR)
#   tue  Hindi (Reshma)  Mathematic   Assembly (nan)                   EVS (HR)
#   wed  Hindi (Reshma)  Mathematic         Marathi                    EVS (HR)
#   thu  Hindi (Reshma)  Mathematic         Marathi                    EVS (HR)
#   fri     Mathematic   Mathematic         EVS (HR)  Computer Studies (Trupti)
#
#                              7th             8th  break      9th  \
#   mon  Computer Studies (Trupti)            Yoga  Break    Music
#   tue           Circle Time (HR)         KARATE   Break  Music T
#   wed                 Life Skill            Art   Break    Dance
#   thu             PE/ CCA Sports            Art   Break  Library
#   fri             PE/ CCA Sports  Clay modelling  Break     DEED
#
#                                10th  dispersal
#   mon                   Wonder time  Dispersal
#   tue  Environmental Education --EE  Dispersal
#   wed                           SGI  Dispersal
#   thu                           SGI  Dispersal
#   fri                  CLASS TESTS   Dispersal  ,
#   'B':      HomeRoom                  1st                  2nd  break  \
#   mon  HomeRoom  Eng (Kanak,Matilda)  Eng (Kanak,Matilda)  Break
#   tue  HomeRoom  Eng (Kanak,Matilda)  Eng (Kanak,Matilda)  Break
#   wed  HomeRoom  Eng (Kanak,Matilda)  Eng (Kanak,Matilda)  Break
#   thu  HomeRoom  Eng (Kanak,Matilda)       Hindi (Reshma)  Break
#   fri  HomeRoom  Eng (Kanak,Matilda)       Hindi (Reshma)  Break
#
#                   3rd          4th             5th  \
#   mon  Hindi (Reshma)  Mathematic      Mathematic
#   tue  Hindi (Reshma)  Mathematic   Assembly (nan)
#   wed  Hindi (Reshma)  Mathematic         Marathi
#   thu  Hindi (Reshma)  Mathematic         Marathi
#   fri     Mathematic   Mathematic         EVS (HR)
#
#                                 6th                           7th  \
#   mon                      EVS (HR)  Computer Studies (Sayantani)
#   tue                      EVS (HR)              Circle Time (HR)
#   wed                      EVS (HR)                    Life Skill
#   thu                      EVS (HR)                PE/ CCA Sports
#   fri  Computer Studies (Sayantani)                PE/ CCA Sports
#
#                   8th  break      9th                          10th  dispersal
#   mon            Yoga  Break    Music                   Wonder time  Dispersal
#   tue         KARATE   Break  Music T  Environmental Education --EE  Dispersal
#   wed            Art   Break    Dance                           SGI  Dispersal
#   thu            Art   Break  Library                           SGI  Dispersal
#   fri  Clay modelling  Break     DEED                  CLASS TESTS   Dispersal  ,
#   'C':      HomeRoom                        1st                        2nd  break  \
#   mon  HomeRoom  Eng ( Rishita,Shashwati,)  Eng ( Rishita,Shashwati,)  Break
#   tue  HomeRoom  Eng ( Rishita,Shashwati,)  Eng ( Rishita,Shashwati,)  Break
#   wed  HomeRoom  Eng ( Rishita,Shashwati,)  Eng ( Rishita,Shashwati,)  Break
#   thu  HomeRoom  Eng ( Rishita,Shashwati,)          Hindi (Santosh K)  Break
#   fri  HomeRoom  Eng ( Rishita,Shashwati,)          Hindi (Santosh K)  Break
#
#                      3rd          4th             5th  \
#   mon  Hindi (Santosh K)  Mathematic      Mathematic
#   tue  Hindi (Santosh K)  Mathematic   Assembly (nan)
#   wed  Hindi (Santosh K)  Mathematic         Marathi
#   thu  Hindi (Santosh K)  Mathematic         Marathi
#   fri        Mathematic   Mathematic         EVS (HR)
#
#                                 6th                           7th  \
#   mon                      EVS (HR)  Computer Studies (Sayantani)
#   tue                      EVS (HR)              Circle Time (HR)
#   wed                      EVS (HR)                    Life Skill
#   thu                      EVS (HR)                PE/ CCA Sports
#   fri  Computer Studies (Sayantani)                PE/ CCA Sports
#
#                   8th  break      9th                          10th  dispersal
#   mon            Yoga  Break    Music                   Wonder time  Dispersal
#   tue         KARATE   Break  Music T  Environmental Education --EE  Dispersal
#   wed            Art   Break    Dance                           SGI  Dispersal
#   thu            Art   Break  Library                           SGI  Dispersal
#   fri  Clay modelling  Break     DEED                  CLASS TESTS   Dispersal  ,
#   'D':      HomeRoom                      1st                      2nd  break  \
#   mon  HomeRoom  Eng (Charu ,Maariyah, )  Eng (Charu ,Maariyah, )  Break
#   tue  HomeRoom  Eng (Charu ,Maariyah, )  Eng (Charu ,Maariyah, )  Break
#   wed  HomeRoom  Eng (Charu ,Maariyah, )  Eng (Charu ,Maariyah, )  Break
#   thu  HomeRoom  Eng (Charu ,Maariyah, )        Hindi (Santosh K)  Break
#   fri  HomeRoom  Eng (Charu ,Maariyah, )        Hindi (Santosh K)  Break
#
#                      3rd          4th             5th  \
#   mon  Hindi (Santosh K)  Mathematic      Mathematic
#   tue  Hindi (Santosh K)  Mathematic   Assembly (nan)
#   wed  Hindi (Santosh K)  Mathematic         Marathi
#   thu  Hindi (Santosh K)  Mathematic         Marathi
#   fri        Mathematic   Mathematic         EVS (HR)
#
#                                 6th                           7th  \
#   mon                      EVS (HR)  Computer Studies (Sayantani)
#   tue                      EVS (HR)              Circle Time (HR)
#   wed                      EVS (HR)                    Life Skill
#   thu                      EVS (HR)                PE/ CCA Sports
#   fri  Computer Studies (Sayantani)                PE/ CCA Sports
#
#                   8th  break      9th                          10th  dispersal
#   mon            Yoga  Break    Music                   Wonder time  Dispersal
#   tue         KARATE   Break  Music T  Environmental Education --EE  Dispersal
#   wed            Art   Break    Dance                           SGI  Dispersal
#   thu            Art   Break  Library                           SGI  Dispersal
#   fri  Clay modelling  Break     DEED                  CLASS TESTS   Dispersal  }}

# %%
 # Create a mock DataFrame for home room teachers
def assign_teachers_with_alternate_hr(timetable, teacher_subject_mapping):
    data = {
    'Class-Section': ['Jr. KG A', 'Jr. KG B', 'Jr. KG C', 'Jr. KG D', 'Sr. KG A', 'Sr. KG B', 'Sr. KG C', 'Sr. KG D', 'I A', 'I B', 'I C', 'I D'],
    'Teachers': [['Kim', 'Rukhsaar'], ['Maria', 'Shital'], ['Shireen', 'Uphaar'], ['Priyanka', 'Darshana'],
                 ['Pooja', 'Nupur'], ['Anjum', 'Lakshmipriya'], ['Shubha', 'Jyoti'], ['Ankita', 'Bhakti'],
                 ['Remya', 'Saraswati'], ['Kanak', 'Matilda'], ['Rishita', 'Shashwati'], ['Charu', 'Maariyah']]
    }
    home_teachers_df = pd.DataFrame(data)
    home_teachers_mapping = dict(zip(home_teachers_df['Class-Section'], home_teachers_df['Teachers']))
    classes = list(timetable.keys())
    sections = list(timetable[classes[0]].keys())
    for cls in classes:
        for section in sections:
            class_section = f"{cls} {section}"
            if class_section not in home_teachers_mapping:
                print(f"Class-Section {class_section} not found in home_teachers_mapping.")
                continue
            hr_teachers = home_teachers_mapping[class_section]
            if len(hr_teachers) < 2:
                print(f"Not enough teachers for HR mapping in {class_section}.")
                continue
            alternate_teacher_index = 0
            rows = timetable[cls][section].index
            columns = timetable[cls][section].columns

            for day in rows:
                for col in columns:
                    if col not in ['break', 'dispersal', 'HomeRoom']:
                        subject = timetable[cls][section].loc[day, col]
                        if "HR" in subject:
                            teacher = hr_teachers[alternate_teacher_index]
                            timetable[cls][section].loc[day, col] = subject.replace("HR", teacher)
                            alternate_teacher_index = (alternate_teacher_index + 1) % len(hr_teachers)
    return timetable
assign_teachers_with_alternate_hr(timetable=timetable, teacher_subject_mapping=teacher_subject_mapping)
# Out:
# {'Jr. KG': {'A':                             1st               2nd         3rd             4th  \
#   mon  eng (Nupur FT , Pooja  R )       hindi (Kim)  mathematic  evs (Rukhsaar)
#   tue  eng (Nupur FT , Pooja  R )          Assembly  mathematic  pe/ cca sports
#   wed  eng (Nupur FT , Pooja  R )       hindi (Kim)  mathematic  pe/ cca sports
#   thu  eng (Nupur FT , Pooja  R )  hindi (Rukhsaar)  mathematic       art (Kim)
#   fri  eng (Nupur FT , Pooja  R )  hindi (Rukhsaar)   evs (Kim)  art (Rukhsaar)
#
#                              5th  break                             6th  \
#   mon  clay modelling (Shridevi)  Break                  assembly (nan)
#   tue           music (Sanjukta)  Break         wonder time (Neesha.R )
#   wed            dance (Pooja B)  Break    environmental education --ee
#   thu          library (Pooja S)  Break    environmental education --ee
#   fri                deed (Isha)  Break  computer studies / circle time
#
#                         7th  dispersal
#   mon     life skill / yoga  Dispersal
#   tue  play pen / role play  Dispersal
#   wed               leisure  Dispersal
#   thu               leisure  Dispersal
#   fri               leisure  Dispersal  ,
#   'B':                     1st             2nd          3rd             4th  \
#   mon  eng (Maria , Banu)   hindi (Maria)   mathematic    evs (Shital)
#   tue  eng (Maria , Banu)        Assembly   mathematic  pe/ cca sports
#   wed  eng (Maria , Banu)   hindi (Maria)   mathematic  pe/ cca sports
#   thu  eng (Maria , Banu)  hindi (Shital)   mathematic     art (Maria)
#   fri  eng (Maria , Banu)  hindi (Shital)  evs (Maria)    art (Shital)
#
#                              5th  break                             6th  \
#   mon  clay modelling (Shridevi)  Break                  assembly (nan)
#   tue           music (Sanjukta)  Break         wonder time (Neesha.R )
#   wed            dance (Pooja B)  Break    environmental education --ee
#   thu          library (Pooja S)  Break    environmental education --ee
#   fri                 deed (nan)  Break  computer studies / circle time
#
#                         7th  dispersal
#   mon     life skill / yoga  Dispersal
#   tue  play pen / role play  Dispersal
#   wed               leisure  Dispersal
#   thu               leisure  Dispersal
#   fri               leisure  Dispersal  ,
#   'C':                          1st              2nd            3rd             4th  \
#   mon  eng (Shireen , Riya J )  hindi (Shireen)     mathematic    evs (Uphaar)
#   tue  eng (Shireen , Riya J )         Assembly     mathematic  pe/ cca sports
#   wed  eng (Shireen , Riya J )  hindi (Shireen)     mathematic  pe/ cca sports
#   thu  eng (Shireen , Riya J )   hindi (Uphaar)     mathematic   art (Shireen)
#   fri  eng (Shireen , Riya J )   hindi (Uphaar)  evs (Shireen)    art (Uphaar)
#
#                              5th  break                             6th  \
#   mon  clay modelling (Shridevi)  Break                  assembly (nan)
#   tue             music (Shlok )  Break         wonder time (Neesha.R )
#   wed            dance (Pooja B)  Break    environmental education --ee
#   thu          library (Pooja S)  Break    environmental education --ee
#   fri                 deed (nan)  Break  computer studies / circle time
#
#                         7th  dispersal
#   mon     life skill / yoga  Dispersal
#   tue  play pen / role play  Dispersal
#   wed               leisure  Dispersal
#   thu               leisure  Dispersal
#   fri               leisure  Dispersal  ,
#   'D':                       1st               2nd             3rd             4th  \
#   mon  eng (Sheetal Anjum )  hindi (Priyanka)      mathematic  evs (Darshana)
#   tue  eng (Sheetal Anjum )          Assembly      mathematic  pe/ cca sports
#   wed  eng (Sheetal Anjum )  hindi (Priyanka)      mathematic  pe/ cca sports
#   thu  eng (Sheetal Anjum )  hindi (Darshana)      mathematic  art (Priyanka)
#   fri  eng (Sheetal Anjum )  hindi (Darshana)  evs (Priyanka)  art (Darshana)
#
#                              5th  break                             6th  \
#   mon  clay modelling (Shridevi)  Break                  assembly (nan)
#   tue             music (Shlok )  Break         wonder time (Neesha.R )
#   wed            dance (Pooja B)  Break    environmental education --ee
#   thu          library (Pooja S)  Break    environmental education --ee
#   fri                 deed (nan)  Break  computer studies / circle time
#
#                         7th  dispersal
#   mon     life skill / yoga  Dispersal
#   tue  play pen / role play  Dispersal
#   wed               leisure  Dispersal
#   thu               leisure  Dispersal
#   fri               leisure  Dispersal  },
#  'Sr. KG': {'A':                         1st            2nd         3rd             4th  \
#   mon  eng (Ruksaar Darshana)  hindi (Pooja)  mathematic     evs (Nupur)
#   tue  eng (Ruksaar Darshana)       Assembly  mathematic     evs (Nupur)
#   wed  eng (Ruksaar Darshana)  hindi (Nupur)  mathematic     evs (Pooja)
#   thu  eng (Ruksaar Darshana)  hindi (Nupur)  mathematic  pe/ cca sports
#   fri  eng (Ruksaar Darshana)  hindi (Pooja)  mathematic  pe/ cca sports
#
#                              5th  break                             6th  \
#   mon                art (Pooja)  Break               library (Pooja S)
#   tue                art (Pooja)  Break         wonder time (Neesha.R )
#   wed  clay modelling (Shridevi)  Break    environmental education --ee
#   thu           music (Sanjukta)  Break  computer studies / circle time
#   fri            dance (Pooja B)  Break               life skill / yoga
#
#                        7th  dispersal
#   mon      deed / assembly  Dispersal
#   tue  play pen / play pen  Dispersal
#   wed              leisure  Dispersal
#   thu              leisure  Dispersal
#   fri              leisure  Dispersal  ,
#   'B':                          1st                   2nd         3rd  \
#   mon  eng (Bhakti Laxmipriya)         hindi (Anjum)  mathematic
#   tue  eng (Bhakti Laxmipriya)              Assembly  mathematic
#   wed  eng (Bhakti Laxmipriya)  hindi (Lakshmipriya)  mathematic
#   thu  eng (Bhakti Laxmipriya)  hindi (Lakshmipriya)  mathematic
#   fri  eng (Bhakti Laxmipriya)         hindi (Anjum)  mathematic
#
#                       4th                        5th  break  \
#   mon  evs (Lakshmipriya)                art (Anjum)  Break
#   tue  evs (Lakshmipriya)                art (Anjum)  Break
#   wed         evs (Anjum)  clay modelling (Shridevi)  Break
#   thu      pe/ cca sports           music (Sanjukta)  Break
#   fri      pe/ cca sports            dance (Pooja B)  Break
#
#                                   6th                  7th  dispersal
#   mon               library (Pooja S)      deed / assembly  Dispersal
#   tue         wonder time (Neesha.R )  play pen / play pen  Dispersal
#   wed    environmental education --ee              leisure  Dispersal
#   thu  computer studies / circle time              leisure  Dispersal
#   fri               life skill / yoga              leisure  Dispersal  ,
#   'C':                              1st             2nd         3rd             4th  \
#   mon  eng ( Shubha FT , Priyanka)  hindi (Shubha)  mathematic     evs (Jyoti)
#   tue  eng ( Shubha FT , Priyanka)        Assembly  mathematic     evs (Jyoti)
#   wed  eng ( Shubha FT , Priyanka)   hindi (Jyoti)  mathematic    evs (Shubha)
#   thu  eng ( Shubha FT , Priyanka)   hindi (Jyoti)  mathematic  pe/ cca sports
#   fri  eng ( Shubha FT , Priyanka)  hindi (Shubha)  mathematic  pe/ cca sports
#
#                              5th  break                             6th  \
#   mon               art (Shubha)  Break               library (Pooja S)
#   tue               art (Shubha)  Break         wonder time (Neesha.R )
#   wed  clay modelling (Shridevi)  Break    environmental education --ee
#   thu             music (Shlok )  Break  computer studies / circle time
#   fri            dance (Pooja B)  Break               life skill / yoga
#
#                        7th  dispersal
#   mon      deed / assembly  Dispersal
#   tue  play pen / play pen  Dispersal
#   wed              leisure  Dispersal
#   thu              leisure  Dispersal
#   fri              leisure  Dispersal  ,
#   'D':                          1st             2nd         3rd             4th  \
#   mon  eng (Ankita\n Jyoti V )  hindi (Ankita)  mathematic    evs (Bhakti)
#   tue  eng (Ankita\n Jyoti V )        Assembly  mathematic    evs (Bhakti)
#   wed  eng (Ankita\n Jyoti V )  hindi (Bhakti)  mathematic    evs (Ankita)
#   thu  eng (Ankita\n Jyoti V )  hindi (Bhakti)  mathematic  pe/ cca sports
#   fri  eng (Ankita\n Jyoti V )  hindi (Ankita)  mathematic  pe/ cca sports
#
#                              5th  break                             6th  \
#   mon               art (Ankita)  Break               library (Pooja S)
#   tue               art (Ankita)  Break         wonder time (Neesha.R )
#   wed  clay modelling (Shridevi)  Break    environmental education --ee
#   thu             music (Shlok )  Break  computer studies / circle time
#   fri            dance (Pooja B)  Break               life skill / yoga
#
#                        7th  dispersal
#   mon      deed / assembly  Dispersal
#   tue  play pen / play pen  Dispersal
#   wed              leisure  Dispersal
#   thu              leisure  Dispersal
#   fri              leisure  Dispersal  },
#  'I': {'A':      HomeRoom                        1st                        2nd  break  \
#   mon  HomeRoom  eng (Remya,Saraswati -FT)  eng (Remya,Saraswati -FT)  Break
#   tue  HomeRoom  eng (Remya,Saraswati -FT)  eng (Remya,Saraswati -FT)  Break
#   wed  HomeRoom  eng (Remya,Saraswati -FT)  eng (Remya,Saraswati -FT)  Break
#   thu  HomeRoom  eng (Remya,Saraswati -FT)             hindi (Reshma)  Break
#   fri  HomeRoom  eng (Remya,Saraswati -FT)             hindi (Reshma)  Break
#
#                   3rd         4th              5th                        6th  \
#   mon  hindi (Reshma)  mathematic       mathematic                evs (Remya)
#   tue  hindi (Reshma)  mathematic         Assembly            evs (Saraswati)
#   wed  hindi (Reshma)  mathematic          marathi            evs (Saraswati)
#   thu  hindi (Reshma)  mathematic          marathi                evs (Remya)
#   fri      mathematic  mathematic  evs (Saraswati)  computer studies (Trupti)
#
#                              7th             8th  break      9th  \
#   mon  computer studies (Trupti)            yoga  Break    music
#   tue        circle time (Remya)          karate  Break  music t
#   wed                 life skill             art  Break    dance
#   thu             pe/ cca sports             art  Break  library
#   fri             pe/ cca sports  clay modelling  Break     deed
#
#                                10th  dispersal
#   mon                      assembly  Dispersal
#   tue                   wonder time  Dispersal
#   wed  environmental education --ee  Dispersal
#   thu                           sgi  Dispersal
#   fri                           sgi  Dispersal  ,
#   'B':      HomeRoom                  1st                  2nd  break  \
#   mon  HomeRoom  eng (Kanak,Matilda)  eng (Kanak,Matilda)  Break
#   tue  HomeRoom  eng (Kanak,Matilda)  eng (Kanak,Matilda)  Break
#   wed  HomeRoom  eng (Kanak,Matilda)  eng (Kanak,Matilda)  Break
#   thu  HomeRoom  eng (Kanak,Matilda)       hindi (Reshma)  Break
#   fri  HomeRoom  eng (Kanak,Matilda)       hindi (Reshma)  Break
#
#                   3rd         4th            5th                           6th  \
#   mon  hindi (Reshma)  mathematic     mathematic                   evs (Kanak)
#   tue  hindi (Reshma)  mathematic       Assembly                 evs (Matilda)
#   wed  hindi (Reshma)  mathematic        marathi                 evs (Matilda)
#   thu  hindi (Reshma)  mathematic        marathi                   evs (Kanak)
#   fri      mathematic  mathematic  evs (Matilda)  computer studies (Sayantani)
#
#                                 7th             8th  break      9th  \
#   mon  computer studies (Sayantani)            yoga  Break    music
#   tue           circle time (Kanak)          karate  Break  music t
#   wed                    life skill             art  Break    dance
#   thu                pe/ cca sports             art  Break  library
#   fri                pe/ cca sports  clay modelling  Break     deed
#
#                                10th  dispersal
#   mon                      assembly  Dispersal
#   tue                   wonder time  Dispersal
#   wed  environmental education --ee  Dispersal
#   thu                           sgi  Dispersal
#   fri                           sgi  Dispersal  ,
#   'C':      HomeRoom                        1st                        2nd  break  \
#   mon  HomeRoom  eng ( Rishita,Shashwati,)  eng ( Rishita,Shashwati,)  Break
#   tue  HomeRoom  eng ( Rishita,Shashwati,)  eng ( Rishita,Shashwati,)  Break
#   wed  HomeRoom  eng ( Rishita,Shashwati,)  eng ( Rishita,Shashwati,)  Break
#   thu  HomeRoom  eng ( Rishita,Shashwati,)          hindi (Santosh K)  Break
#   fri  HomeRoom  eng ( Rishita,Shashwati,)          hindi (Santosh K)  Break
#
#                      3rd         4th              5th  \
#   mon  hindi (Santosh K)  mathematic       mathematic
#   tue  hindi (Santosh K)  mathematic         Assembly
#   wed  hindi (Santosh K)  mathematic          marathi
#   thu  hindi (Santosh K)  mathematic          marathi
#   fri         mathematic  mathematic  evs (Shashwati)
#
#                                 6th                           7th  \
#   mon                 evs (Rishita)  computer studies (Sayantani)
#   tue               evs (Shashwati)         circle time (Rishita)
#   wed               evs (Shashwati)                    life skill
#   thu                 evs (Rishita)                pe/ cca sports
#   fri  computer studies (Sayantani)                pe/ cca sports
#
#                   8th  break      9th                          10th  dispersal
#   mon            yoga  Break    music                      assembly  Dispersal
#   tue          karate  Break  music t                   wonder time  Dispersal
#   wed             art  Break    dance  environmental education --ee  Dispersal
#   thu             art  Break  library                           sgi  Dispersal
#   fri  clay modelling  Break     deed                           sgi  Dispersal  ,
#   'D':      HomeRoom                      1st                      2nd  break  \
#   mon  HomeRoom  eng (Charu ,Maariyah, )  eng (Charu ,Maariyah, )  Break
#   tue  HomeRoom  eng (Charu ,Maariyah, )  eng (Charu ,Maariyah, )  Break
#   wed  HomeRoom  eng (Charu ,Maariyah, )  eng (Charu ,Maariyah, )  Break
#   thu  HomeRoom  eng (Charu ,Maariyah, )        hindi (Santosh K)  Break
#   fri  HomeRoom  eng (Charu ,Maariyah, )        hindi (Santosh K)  Break
#
#                      3rd         4th             5th  \
#   mon  hindi (Santosh K)  mathematic      mathematic
#   tue  hindi (Santosh K)  mathematic        Assembly
#   wed  hindi (Santosh K)  mathematic         marathi
#   thu  hindi (Santosh K)  mathematic         marathi
#   fri         mathematic  mathematic  evs (Maariyah)
#
#                                 6th                           7th  \
#   mon                   evs (Charu)  computer studies (Sayantani)
#   tue                evs (Maariyah)           circle time (Charu)
#   wed                evs (Maariyah)                    life skill
#   thu                   evs (Charu)                pe/ cca sports
#   fri  computer studies (Sayantani)                pe/ cca sports
#
#                   8th  break      9th                          10th  dispersal
#   mon            yoga  Break    music                      assembly  Dispersal
#   tue          karate  Break  music t                   wonder time  Dispersal
#   wed             art  Break    dance  environmental education --ee  Dispersal
#   thu             art  Break  library                           sgi  Dispersal
#   fri  clay modelling  Break     deed                           sgi  Dispersal  }}

# %%
# Step 9: Save the timetables to Excel
writer = pd.ExcelWriter('/content/Generated_Timetables.xlsx', engine='xlsxwriter')

for cls in classes:
    for section in sections:
        timetable[cls][section].to_excel(writer, sheet_name=f"{cls}_{section}")

writer.close()
print("Timetables generated and saved successfully.")

# %%
def validate_period_frequencies(timetable, period_allotment):
    for cls in timetable:
        for section in timetable[cls]:
            # Iterate over all days and slots in the timetable
            for day in timetable[cls][section].index:
                for slot in timetable[cls][section].columns:
                    if slot in ['break', 'dispersal', 'HR']:  # Skip non-teaching periods
                        continue

                    subject = timetable[cls][section].at[day, slot]

                    if subject != '':  # Skip empty slots
                        # Get the expected frequency from period_allotment
                        frequency = period_allotment.loc[period_allotment['Subject'] == subject, cls].values

                        if frequency.size > 0:  # Check if frequency exists for the subject
                            expected_frequency = frequency[0]

                            # Count the actual frequency of the subject in the timetable
                            actual_frequency = (timetable[cls][section] == subject).sum().sum()

                            # Compare actual and expected frequencies
                            if actual_frequency != expected_frequency:
                                print(f"Warning: Frequency mismatch for {subject} in {cls}-{section}.\n"
                                      f"Expected: {expected_frequency}, Found: {actual_frequency}")
                        else:
                            print(f"Warning: {subject} is not found in period_allotment for {cls}-{section}.")
                    else:
                        continue  # Skip empty slots



validate_period_frequencies(timetable, period_allotment)
# Out:
# Warning: PLAY PEN  / Role play is not found in period_allotment for Jr. KG-A.
# Warning: leisure is not found in period_allotment for Jr. KG-A.
# Warning: leisure is not found in period_allotment for Jr. KG-A.
# Warning: Computer Studies / Circle Time is not found in period_allotment for Jr. KG-A.
# Warning: leisure is not found in period_allotment for Jr. KG-A.
# Warning: Life Skill / Yoga is not found in period_allotment for Jr. KG-A.
# Warning: leisure is not found in period_allotment for Jr. KG-A.
# Warning: PLAY PEN  / Role play is not found in period_allotment for Jr. KG-B.
# Warning: leisure is not found in period_allotment for Jr. KG-B.
# Warning: leisure is not found in period_allotment for Jr. KG-B.
# Warning: Computer Studies / Circle Time is not found in period_allotment for Jr. KG-B.
# Warning: leisure is not found in period_allotment for Jr. KG-B.
# Warning: Life Skill / Yoga is not found in period_allotment for Jr. KG-B.
# Warning: leisure is not found in period_allotment for Jr. KG-B.
# Warning: PLAY PEN  / Role play is not found in period_allotment for Jr. KG-C.
# Warning: leisure is not found in period_allotment for Jr. KG-C.
# Warning: leisure is not found in period_allotment for Jr. KG-C.
# Warning: Computer Studies / Circle Time is not found in period_allotment for Jr. KG-C.
# Warning: leisure is not found in period_allotment for Jr. KG-C.
# Warning: Life Skill / Yoga is not found in period_allotment for Jr. KG-C.
# Warning: leisure is not found in period_allotment for Jr. KG-C.
# Warning: PLAY PEN  / Role play is not found in period_allotment for Jr. KG-D.
# Warning: leisure is not found in period_allotment for Jr. KG-D.
# Warning: leisure is not found in period_allotment for Jr. KG-D.
# Warning: Computer Studies / Circle Time is not found in period_allotment for Jr. KG-D.
# Warning: leisure is not found in period_allotment for Jr. KG-D.
# Warning: Life Skill / Yoga is not found in period_allotment for Jr. KG-D.
# Warning: leisure is not found in period_allotment for Jr. KG-D.
# Warning: Frequency mismatch for Mathematic  in Sr. KG-A.
# Expected: 4.5, Found: 5
# Warning: DEED / Assembly is not found in period_allotment for Sr. KG-A.
# Warning: Frequency mismatch for Assembly in Sr. KG-A.
# Expected: 0.5, Found: 1
# Warning: Frequency mismatch for Mathematic  in Sr. KG-A.
# Expected: 4.5, Found: 5
# Warning: PLAY PEN  / PLAY PEN  is not found in period_allotment for Sr. KG-A.
# Warning: Frequency mismatch for Mathematic  in Sr. KG-A.
# Expected: 4.5, Found: 5
# Warning: leisure is not found in period_allotment for Sr. KG-A.
# Warning: Frequency mismatch for Mathematic  in Sr. KG-A.
# Expected: 4.5, Found: 5
# Warning: Computer Studies / Circle Time is not found in period_allotment for Sr. KG-A.
# Warning: leisure is not found in period_allotment for Sr. KG-A.
# Warning: Frequency mismatch for Mathematic  in Sr. KG-A.
# Expected: 4.5, Found: 5
# Warning: Life Skill / Yoga is not found in period_allotment for Sr. KG-A.
# Warning: leisure is not found in period_allotment for Sr. KG-A.
# Warning: Frequency mismatch for Mathematic  in Sr. KG-B.
# Expected: 4.5, Found: 5
# Warning: DEED / Assembly is not found in period_allotment for Sr. KG-B.
# Warning: Frequency mismatch for Assembly in Sr. KG-B.
# Expected: 0.5, Found: 1
# Warning: Frequency mismatch for Mathematic  in Sr. KG-B.
# Expected: 4.5, Found: 5
# Warning: PLAY PEN  / PLAY PEN  is not found in period_allotment for Sr. KG-B.
# Warning: Frequency mismatch for Mathematic  in Sr. KG-B.
# Expected: 4.5, Found: 5
# Warning: leisure is not found in period_allotment for Sr. KG-B.
# Warning: Frequency mismatch for Mathematic  in Sr. KG-B.
# Expected: 4.5, Found: 5
# Warning: Computer Studies / Circle Time is not found in period_allotment for Sr. KG-B.
# Warning: leisure is not found in period_allotment for Sr. KG-B.
# Warning: Frequency mismatch for Mathematic  in Sr. KG-B.
# Expected: 4.5, Found: 5
# Warning: Life Skill / Yoga is not found in period_allotment for Sr. KG-B.
# Warning: leisure is not found in period_allotment for Sr. KG-B.
# Warning: Frequency mismatch for Mathematic  in Sr. KG-C.
# Expected: 4.5, Found: 5
# Warning: DEED / Assembly is not found in period_allotment for Sr. KG-C.
# Warning: Frequency mismatch for Assembly in Sr. KG-C.
# Expected: 0.5, Found: 1
# Warning: Frequency mismatch for Mathematic  in Sr. KG-C.
# Expected: 4.5, Found: 5
# Warning: PLAY PEN  / PLAY PEN  is not found in period_allotment for Sr. KG-C.
# Warning: Frequency mismatch for Mathematic  in Sr. KG-C.
# Expected: 4.5, Found: 5
# Warning: leisure is not found in period_allotment for Sr. KG-C.
# Warning: Frequency mismatch for Mathematic  in Sr. KG-C.
# Expected: 4.5, Found: 5
# Warning: Computer Studies / Circle Time is not found in period_allotment for Sr. KG-C.
# Warning: leisure is not found in period_allotment for Sr. KG-C.
# Warning: Frequency mismatch for Mathematic  in Sr. KG-C.
# Expected: 4.5, Found: 5
# Warning: Life Skill / Yoga is not found in period_allotment for Sr. KG-C.
# Warning: leisure is not found in period_allotment for Sr. KG-C.
# Warning: Frequency mismatch for Mathematic  in Sr. KG-D.
# Expected: 4.5, Found: 5
# Warning: DEED / Assembly is not found in period_allotment for Sr. KG-D.
# Warning: Frequency mismatch for Assembly in Sr. KG-D.
# Expected: 0.5, Found: 1
# Warning: Frequency mismatch for Mathematic  in Sr. KG-D.
# Expected: 4.5, Found: 5
# Warning: PLAY PEN  / PLAY PEN  is not found in period_allotment for Sr. KG-D.
# Warning: Frequency mismatch for Mathematic  in Sr. KG-D.
# Expected: 4.5, Found: 5
# Warning: leisure is not found in period_allotment for Sr. KG-D.
# Warning: Frequency mismatch for Mathematic  in Sr. KG-D.
# Expected: 4.5, Found: 5
# Warning: Computer Studies / Circle Time is not found in period_allotment for Sr. KG-D.
# Warning: leisure is not found in period_allotment for Sr. KG-D.
# Warning: Frequency mismatch for Mathematic  in Sr. KG-D.
# Expected: 4.5, Found: 5
# Warning: Life Skill / Yoga is not found in period_allotment for Sr. KG-D.
# Warning: leisure is not found in period_allotment for Sr. KG-D.
# Warning: HomeRoom is not found in period_allotment for I-A.
# Warning: HomeRoom is not found in period_allotment for I-A.
# Warning: HomeRoom is not found in period_allotment for I-A.
# Warning: HomeRoom is not found in period_allotment for I-A.
# Warning: HomeRoom is not found in period_allotment for I-A.
# Warning: HomeRoom is not found in period_allotment for I-B.
# Warning: HomeRoom is not found in period_allotment for I-B.
# Warning: HomeRoom is not found in period_allotment for I-B.
# Warning: HomeRoom is not found in period_allotment for I-B.
# Warning: HomeRoom is not found in period_allotment for I-B.
# Warning: HomeRoom is not found in period_allotment for I-C.
# Warning: HomeRoom is not found in period_allotment for I-C.
# Warning: HomeRoom is not found in period_allotment for I-C.
# Warning: HomeRoom is not found in period_allotment for I-C.
# Warning: HomeRoom is not found in period_allotment for I-C.
# Warning: HomeRoom is not found in period_allotment for I-D.
# Warning: HomeRoom is not found in period_allotment for I-D.
# Warning: HomeRoom is not found in period_allotment for I-D.
# Warning: HomeRoom is not found in period_allotment for I-D.
# Warning: HomeRoom is not found in period_allotment for I-D.

# %%
import pandas as pd
import random
import xlsxwriter

# Step 1: Load the Excel file and read the sheets
data_path = '/content/TimeTable Project.xlsx'
data = pd.ExcelFile(data_path)

# Step 2: Read the sheets for period allotment and teacher-subject mapping
period_allotment = data.parse('Period Allotment')  # Adjust the sheet name as per your file
teacher_subject_mapping = data.parse('Teacher-Subject Mapping')  # Adjust the sheet name as per your file
home_teachers_df = data.parse('Teacher Subject Mapping 2')
teacher_subject_mapping.columns = teacher_subject_mapping.columns.str.strip()
teacher_subject_mapping.rename(columns={"I A": "IA"}, inplace=True)


# Step 3: Inspect the sheets to ensure data is loaded correctly
period_allotment['Jr. KG'] = pd.to_numeric(period_allotment['Jr. KG'], errors='coerce')
period_allotment['Sr. KG'] = pd.to_numeric(period_allotment['Sr. KG'], errors='coerce')
period_allotment['I'] = pd.to_numeric(period_allotment['I'], errors='coerce')
period_allotment.fillna(0, inplace=True)
period_allotment = period_allotment[period_allotment['Subject'].apply(lambda x: isinstance(x, str) and x.strip() != "0")]

#print(period_allotment.isna().sum())
#print("Period Allotment\n", period_allotment.head())
#print("Teacher Subject Mapping\n", teacher_subject_mapping.head())
# Clean up the teacher names: strip extra spaces from each teacher's name using .apply()


# Step 4: Preprocess the data
# Convert period allotment into a usable format
period_allotment = period_allotment.fillna(0)



# Step 5: Define key constraints
# Number of periods per day and other constraints
PERIODS_PER_DAY = 10  # Excluding breaks and dispersal
DAYS_PER_WEEK = 5
PERIOD_DURATION = 30  # in minutes

#empty table structure
columns = ['1st', '2nd','3rd', '4th','5th','break', '6th', '7th','dispersal']
rows = ['mon', 'tue', 'wed', 'thu', 'fri']
columns1 = ['HomeRoom', '1st', '2nd','break', '3rd', '4th','5th', '6th', '7th','8th','break','9th','10th','dispersal']

# Step 6: Create a blank timetable structure
def initialize_timetable(classes, sections):
    timetable = {}
    for cls in classes:
        timetable[cls] = {}
        for section in sections:
            if cls in ['Jr. KG', 'Sr. KG']:
                # Jr.KG and Sr.KG timetable structure
                timetable[cls][section] = pd.DataFrame(' ', index=rows, columns=columns)
            elif cls == 'I':
                # Class I timetable structure
                timetable[cls][section] = pd.DataFrame(' ', index=rows, columns=columns1)
    return timetable

def fill_common_columns(timetable):
    # Define the common columns and their respective values
    common_columns = {
        'break': 'Break',
        'dispersal': 'Dispersal',
        'HomeRoom': 'HomeRoom'
    }

    # Iterate over all classes in the timetable
    for cls, sections in timetable.items():
        # Iterate over all sections in each class
        for section, df in sections.items():
            # Update common columns for the current DataFrame
            for column, value in common_columns.items():
                if column in df.columns:  # Check if the column exists in the DataFrame
                    df[column] = value  # Fill the entire column with the respective value

    return timetable

def add_assembly(timetable):
    # Define the fixed assembly schedule
    assembly_schedule = {
        'Jr. KG': {'day': 'tue', 'period': '2nd'},  # Jr. KG Assembly during 2nd period
        'Sr. KG': {'day': 'tue', 'period': '2nd'},  # Sr. KG Assembly during 2nd period
        'I': {'day': 'tue', 'period': '5th'}       # Class I Assembly during 5th period
    }

    # Iterate over classes and sections to add "Assembly"
    for cls, sections in timetable.items():
        if cls in assembly_schedule:  # Check if the class has an assembly schedule
            assembly_day = assembly_schedule[cls]['day']
            assembly_period = assembly_schedule[cls]['period']
            for section, df in sections.items():
                if assembly_day in df.index and assembly_period in df.columns:
                    df.loc[assembly_day, assembly_period] = 'Assembly'
    return timetable



classes = ['Jr. KG', 'Sr. KG', 'I']
sections = ['A', 'B', 'C', 'D']
timetable = initialize_timetable(classes, sections)

def pair_half_frequency_subjects(period_allotment):
    paired_subjects = {}
    for cls in ['Jr. KG', 'Sr. KG', 'I']:
        # Extract subjects with 0.5 frequency for this class
        half_freq_subjects = period_allotment[['Subject', cls]]
        # Skip rows where frequency is NaN
        subjects = half_freq_subjects[half_freq_subjects[cls] == 0.5]['Subject'].dropna().tolist()
        # Print subjects with 0.5 frequency for debugging
        #print(f"0.5 Frequency Subjects for {cls}: {subjects}")
        # Handle odd-length lists by leaving the last subject unpaired
        paired_subjects[cls] = [
            (subjects[i], subjects[i+1])
            for i in range(0, len(subjects) - 1, 2)
        ]
        # If there is an unpaired subject, append it with itself
        if len(subjects) % 2 == 1:
            paired_subjects[cls].append((subjects[-1], subjects[-1]))
    return paired_subjects
# Generate pairs
paired_subjects = pair_half_frequency_subjects(period_allotment)
print(paired_subjects)


# def allocate_combined_half_frequency_subjects(timetable, paired_subjects):
#     # Iterate over each class
#     for cls, pairs in paired_subjects.items():
#         # Combine each pair into a single unit (e.g., "Computer Studies / Circle Time")
#         combined_pairs = [f"{pair[0]} / {pair[1]}" for pair in pairs]
#         print(f"Processing class: {cls}")
#         print(f"Combined pairs for {cls}: {combined_pairs}")

#         # Assign combined pairs to the timetable
#         for section, days in timetable[cls].items():
#             print(f"Processing {cls} - {section}: {days}")

#             for day, periods in days.items():
#                 # Find empty slots in the timetable
#                 empty_slots = [i for i, period in enumerate(periods) if period.strip() == '']

#                 # Allocate combined pairs to empty slots only once
#                 for pair in combined_pairs:
#                     if empty_slots:
#                         # Assign the pair to the first available empty slot
#                         periods[empty_slots[0]] = pair
#                         print(f"Allocated '{pair}' to {cls} on {day}, slot {empty_slots[0]}")
#                         # Remove the used slot from the list
#                         empty_slots.pop(0)
#                     # If no empty slots are left, stop allocation for the day
#                     if not empty_slots:
#                         break

#     return timetable

def allocate_combined_half_frequency_subjects(timetable, paired_subjects):
    # Iterate over each class
    for cls, pairs in paired_subjects.items():
        # Combine each pair into a single unit (e.g., "Computer Studies / Circle Time")
        combined_pairs = [f"{pair[0]} / {pair[1]}" for pair in pairs]
        print(f"Processing class: {cls}")
        print(f"Combined pairs for {cls}: {combined_pairs}")

        # Assign combined pairs to the timetable
        for section, days in timetable[cls].items():
            print(f"Processing {cls} - {section}: {days}")

            # Create a set to track already allocated pairs for each day
            allocated_pairs = set()

            for day, periods in days.items():
                if day in ['break', 'dispersal']:
                    print(f"Skipping {day} for {cls} as it is not a class day.")
                    continue
                print(f"Processing day: {day}")
                # Find empty slots in the timetable
                empty_slots = [i for i, period in enumerate(periods) if period.strip() == '']
                print(f"Empty slots for {cls} on {day}: {empty_slots}")

                # If no empty slots are found, continue to next day
                if not empty_slots:
                    print(f"No empty slots for {cls} on {day}, skipping.")
                    continue

                # Allocate combined pairs to empty slots only once
                for pair in combined_pairs:
                    if pair not in allocated_pairs and empty_slots:
                        # Assign the pair to the first available empty slot
                        periods[empty_slots[0]] = pair
                        print(f"Allocated '{pair}' to {cls} on {day}, slot {empty_slots[0]}")
                        # Mark this pair as allocated
                        allocated_pairs.add(pair)
                        # Remove the used slot from the list
                        empty_slots.pop(0)

                        # If all pairs are allocated, break out of the loop
                        if len(allocated_pairs) == len(combined_pairs):
                            print(f"All pairs allocated for {cls} on {day}")
                            break
                for i in empty_slots:
                    periods[i] = "leisure"

    return timetable


# Helper function for subject allocation
# def allocate_subjects(timetable, period_allotment):
#     period_allotment = {subject: freq for subject, freq in period_allotment.items() if subject != 'Assembly'}
#     for subject, frequency in period_allotment.items():
#         periods_allocated = 0
#         # Iterate over each period (slot)
#         for slot in timetable.columns:
#             if slot in ['break', 'dispersal', 'HR']:  # Skip non-teaching periods
#                 continue
#             # Iterate over each day for the current period (slot)
#             for day in timetable.index:
#                 if periods_allocated >= frequency:  # Stop if the subject's frequency is met
#                     break
#                 if timetable.at[day, slot].strip() == '':  # If the slot is empty
#                     timetable.at[day, slot] = subject
#                     periods_allocated += 1
#                     if periods_allocated >= frequency:  # Stop if frequency is met
#                         break
#             if periods_allocated >= frequency:  # Stop if the subject's frequency is met
#                 break
#         # Check if all periods were allocated, if not, issue a warning
#         if periods_allocated < frequency:
#             print(f"Warning: Not enough slots to allocate {frequency} periods of {subject}. Allocated {periods_allocated} periods.")
#     return timetable

def allocate_subjects(timetable, period_allotment):
    # Remove 'Assembly' from the allocation
    period_allotment = {subject: freq for subject, freq in period_allotment.items() if subject != 'Assembly' and freq != 0.5}
    for subject, frequency in period_allotment.items():
        periods_allocated = 0
        # Iterate over each period (slot)
        for slot in timetable.columns:
            if slot in ['break', 'dispersal', 'HomeRoom']:  # Skip non-teaching periods
                continue
            # Iterate over each day for the current period (slot)
            for day in timetable.index:
                if periods_allocated >= frequency:  # Stop if the subject's frequency is met
                    break
                # Check for an empty slot
                if timetable.at[day, slot].strip() == '':  # If the slot is empty
                    timetable.at[day, slot] = subject
                    periods_allocated += 1
                if periods_allocated >= frequency:  # Stop if frequency is met
                    break
            if periods_allocated >= frequency:  # Stop if the subject's frequency is met
                break

        # Check if all periods were allocated, if not, issue a warning
        if periods_allocated < frequency:
            print(f"Warning: Not enough slots to allocate {frequency} periods of {subject}. Allocated {periods_allocated} periods.")

    return timetable



def assign_teachers(timetable, teacher_subject_mapping):
    for cls in classes:
        for section in sections:
            # Remove spaces when constructing class_section for "I" classes
            class_section = f"{cls}{' ' if cls != 'I' else ''}{section}"
            if class_section not in teacher_subject_mapping.columns:
                print(f"Class-Section {class_section} not found in teacher_subject_mapping.")
                continue

            for day in rows:
                for col in columns:
                    if col not in ['break', 'dispersal', 'HomeRoom']:
                        subject = timetable[cls][section].loc[day, col]
                        if subject != '':
                            # print("in") # Debug statement Get the teacher(s)
                            # for this subject and class-section
                            teachers = teacher_subject_mapping.loc[
                                teacher_subject_mapping['Subject'] == subject,
                                class_section
                            ].values
                            if teachers.size > 0:
                                timetable[cls][section].loc[day, col] += f" ({teachers[0]})"

add_assembly(timetable)
# Debugging subject allocation
for cls in classes:
    for section in sections:
        if cls in period_allotment.columns:
            # Extract period allotment for the specific class
            period_allotment_class = period_allotment[['Subject', cls]]
            period_allotment_class = period_allotment_class.set_index('Subject').to_dict()[cls]

            # Allocate subjects to the timetable
            timetable[cls][section] = allocate_subjects(timetable[cls][section], period_allotment_class)
        else:
            print(f"Class {cls} not found in period_allotment columns")

# Debugging teacher assignment
timetable = allocate_combined_half_frequency_subjects(timetable, paired_subjects)
assign_teachers(timetable, teacher_subject_mapping)
fill_common_columns(timetable)




def assign_teachers_with_alternate_hr(timetable, teacher_subject_mapping):
    # Create a mock DataFrame for home room teachers# Create a mock DataFrame for home room teachers
    data = {
    'Class-Section': ['Jr. KG A', 'Jr. KG B', 'Jr. KG C', 'Jr. KG D', 'Sr. KG A', 'Sr. KG B', 'Sr. KG C', 'Sr. KG D', 'I A', 'I B', 'I C', 'I D'],
    'Teachers': [['Kim', 'Rukhsaar'], ['Maria', 'Shital'], ['Shireen', 'Uphaar'], ['Priyanka', 'Darshana'],
                 ['Pooja', 'Nupur'], ['Anjum', 'Lakshmipriya'], ['Shubha', 'Jyoti'], ['Ankita', 'Bhakti'],
                 ['Remya', 'Saraswati'], ['Kanak', 'Matilda'], ['Rishita', 'Shashwati'], ['Charu', 'Maariyah']]
    }
    # Convert the "Home room Teachers" data into a dictionary for easy lookup
    home_teachers_df = pd.DataFrame(data)
    home_teachers_mapping = dict(zip(home_teachers_df['Class-Section'], home_teachers_df['Teachers']))

    classes = list(timetable.keys())  # Extract classes from timetable keys
    sections = list(timetable[classes[0]].keys())  # Extract sections from one class's timetable

    for cls in classes:
        for section in sections:
            # Construct class-section key
            class_section = f"{cls} {section}"
            if class_section not in home_teachers_mapping:
                print(f"Class-Section {class_section} not found in home_teachers_mapping.")
                continue

            # Get the two teachers for this class-section
            hr_teachers = home_teachers_mapping[class_section]
            if len(hr_teachers) < 2:
                print(f"Not enough teachers for HR mapping in {class_section}.")
                continue

            # Initialize alternate HR mapping
            alternate_teacher_index = 0
            rows = timetable[cls][section].index
            columns = timetable[cls][section].columns

            for day in rows:
                for col in columns:
                    if col not in ['break', 'dispersal', 'HomeRoom']:
                        subject = timetable[cls][section].loc[day, col]
                        if "HR" in subject:  # Check for HR
                            # Assign alternate HR teacher
                            teacher = hr_teachers[alternate_teacher_index]
                            timetable[cls][section].loc[day, col] = subject.replace("HR", teacher)
                            # Switch to the next teacher for alternate mapping
                            alternate_teacher_index = (alternate_teacher_index + 1) % len(hr_teachers)

    return timetable

assign_teachers_with_alternate_hr(timetable=timetable, teacher_subject_mapping=teacher_subject_mapping)

# Step 9: Save the timetables to Excel
writer = pd.ExcelWriter('/content/Generated_Timetables.xlsx', engine='xlsxwriter')

for cls in classes:
    for section in sections:
        timetable[cls][section].to_excel(writer, sheet_name=f"{cls}_{section}")

writer.close()
print("Timetables generated and saved successfully.")
# Out:
# {'Jr. KG': [('Computer Studies', 'Circle Time'), ('Life Skill', 'Yoga'), ('PLAY PEN ', 'Role play')], 'Sr. KG': [('Computer Studies', 'Circle Time'), ('Life Skill', 'Yoga'), ('DEED', 'Assembly'), ('PLAY PEN ', 'PLAY PEN ')], 'I': []}
# Processing class: Jr. KG
# Combined pairs for Jr. KG: ['Computer Studies / Circle Time', 'Life Skill / Yoga', 'PLAY PEN  / Role play']
# Processing Jr. KG - A:      1st       2nd          3rd             4th             5th break  \
# mon  Eng     Hindi  Mathematic              EVS  Clay modelling
# tue  Eng  Assembly  Mathematic   PE/ CCA Sports           Music
# wed  Eng     Hindi  Mathematic   PE/ CCA Sports           Dance
# thu  Eng     Hindi  Mathematic             Art          Library
# fri  Eng     Hindi          EVS            Art             DEED
#
#                               6th 7th dispersal
# mon                   Wonder time
# tue  Environmental Education --EE
# wed  Environmental Education --EE
# thu
# fri
# Processing day: 1st
# Empty slots for Jr. KG on 1st: []
# No empty slots for Jr. KG on 1st, skipping.
# Processing day: 2nd
# Empty slots for Jr. KG on 2nd: []
# No empty slots for Jr. KG on 2nd, skipping.
# Processing day: 3rd
# Empty slots for Jr. KG on 3rd: []
# No empty slots for Jr. KG on 3rd, skipping.
# Processing day: 4th
# Empty slots for Jr. KG on 4th: []
# No empty slots for Jr. KG on 4th, skipping.
# Processing day: 5th
# Empty slots for Jr. KG on 5th: []
# No empty slots for Jr. KG on 5th, skipping.
# Skipping break for Jr. KG as it is not a class day.
# Processing day: 6th
# Empty slots for Jr. KG on 6th: [3, 4]
# Allocated 'Computer Studies / Circle Time' to Jr. KG on 6th, slot 3
# Allocated 'Life Skill / Yoga' to Jr. KG on 6th, slot 4
# Processing day: 7th
# Empty slots for Jr. KG on 7th: [0, 1, 2, 3, 4]
# Allocated 'PLAY PEN  / Role play' to Jr. KG on 7th, slot 0
# All pairs allocated for Jr. KG on 7th
# Skipping dispersal for Jr. KG as it is not a class day.
# Processing Jr. KG - B:      1st       2nd          3rd             4th             5th break  \
# mon  Eng     Hindi  Mathematic              EVS  Clay modelling
# tue  Eng  Assembly  Mathematic   PE/ CCA Sports           Music
# wed  Eng     Hindi  Mathematic   PE/ CCA Sports           Dance
# thu  Eng     Hindi  Mathematic             Art          Library
# fri  Eng     Hindi          EVS            Art             DEED
#
#                               6th 7th dispersal
# mon                   Wonder time
# tue  Environmental Education --EE
# wed  Environmental Education --EE
# thu
# fri
# Processing day: 1st
# Empty slots for Jr. KG on 1st: []
# No empty slots for Jr. KG on 1st, skipping.
# Processing day: 2nd
# Empty slots for Jr. KG on 2nd: []
# No empty slots for Jr. KG on 2nd, skipping.
# Processing day: 3rd
# Empty slots for Jr. KG on 3rd: []
# No empty slots for Jr. KG on 3rd, skipping.
# Processing day: 4th
# Empty slots for Jr. KG on 4th: []
# No empty slots for Jr. KG on 4th, skipping.
# Processing day: 5th
# Empty slots for Jr. KG on 5th: []
# No empty slots for Jr. KG on 5th, skipping.
# Skipping break for Jr. KG as it is not a class day.
# Processing day: 6th
# Empty slots for Jr. KG on 6th: [3, 4]
# Allocated 'Computer Studies / Circle Time' to Jr. KG on 6th, slot 3
# Allocated 'Life Skill / Yoga' to Jr. KG on 6th, slot 4
# Processing day: 7th
# Empty slots for Jr. KG on 7th: [0, 1, 2, 3, 4]
# Allocated 'PLAY PEN  / Role play' to Jr. KG on 7th, slot 0
# All pairs allocated for Jr. KG on 7th
# Skipping dispersal for Jr. KG as it is not a class day.
# Processing Jr. KG - C:      1st       2nd          3rd             4th             5th break  \
# mon  Eng     Hindi  Mathematic              EVS  Clay modelling
# tue  Eng  Assembly  Mathematic   PE/ CCA Sports           Music
# wed  Eng     Hindi  Mathematic   PE/ CCA Sports           Dance
# thu  Eng     Hindi  Mathematic             Art          Library
# fri  Eng     Hindi          EVS            Art             DEED
#
#                               6th 7th dispersal
# mon                   Wonder time
# tue  Environmental Education --EE
# wed  Environmental Education --EE
# thu
# fri
# Processing day: 1st
# Empty slots for Jr. KG on 1st: []
# No empty slots for Jr. KG on 1st, skipping.
# Processing day: 2nd
# Empty slots for Jr. KG on 2nd: []
# No empty slots for Jr. KG on 2nd, skipping.
# Processing day: 3rd
# Empty slots for Jr. KG on 3rd: []
# No empty slots for Jr. KG on 3rd, skipping.
# Processing day: 4th
# Empty slots for Jr. KG on 4th: []
# No empty slots for Jr. KG on 4th, skipping.
# Processing day: 5th
# Empty slots for Jr. KG on 5th: []
# No empty slots for Jr. KG on 5th, skipping.
# Skipping break for Jr. KG as it is not a class day.
# Processing day: 6th
# Empty slots for Jr. KG on 6th: [3, 4]
# Allocated 'Computer Studies / Circle Time' to Jr. KG on 6th, slot 3
# Allocated 'Life Skill / Yoga' to Jr. KG on 6th, slot 4
# Processing day: 7th
# Empty slots for Jr. KG on 7th: [0, 1, 2, 3, 4]
# Allocated 'PLAY PEN  / Role play' to Jr. KG on 7th, slot 0
# All pairs allocated for Jr. KG on 7th
# Skipping dispersal for Jr. KG as it is not a class day.
# Processing Jr. KG - D:      1st       2nd          3rd             4th             5th break  \
# mon  Eng     Hindi  Mathematic              EVS  Clay modelling
# tue  Eng  Assembly  Mathematic   PE/ CCA Sports           Music
# wed  Eng     Hindi  Mathematic   PE/ CCA Sports           Dance
# thu  Eng     Hindi  Mathematic             Art          Library
# fri  Eng     Hindi          EVS            Art             DEED
#
#                               6th 7th dispersal
# mon                   Wonder time
# tue  Environmental Education --EE
# wed  Environmental Education --EE
# thu
# fri
# Processing day: 1st
# Empty slots for Jr. KG on 1st: []
# No empty slots for Jr. KG on 1st, skipping.
# Processing day: 2nd
# Empty slots for Jr. KG on 2nd: []
# No empty slots for Jr. KG on 2nd, skipping.
# Processing day: 3rd
# Empty slots for Jr. KG on 3rd: []
# No empty slots for Jr. KG on 3rd, skipping.
# Processing day: 4th
# Empty slots for Jr. KG on 4th: []
# No empty slots for Jr. KG on 4th, skipping.
# Processing day: 5th
# Empty slots for Jr. KG on 5th: []
# No empty slots for Jr. KG on 5th, skipping.
# Skipping break for Jr. KG as it is not a class day.
# Processing day: 6th
# Empty slots for Jr. KG on 6th: [3, 4]
# Allocated 'Computer Studies / Circle Time' to Jr. KG on 6th, slot 3
# Allocated 'Life Skill / Yoga' to Jr. KG on 6th, slot 4
# Processing day: 7th
# Empty slots for Jr. KG on 7th: [0, 1, 2, 3, 4]
# Allocated 'PLAY PEN  / Role play' to Jr. KG on 7th, slot 0
# All pairs allocated for Jr. KG on 7th
# Skipping dispersal for Jr. KG as it is not a class day.
# Processing class: Sr. KG
# Combined pairs for Sr. KG: ['Computer Studies / Circle Time', 'Life Skill / Yoga', 'DEED / Assembly', 'PLAY PEN  / PLAY PEN ']
# Processing Sr. KG - A:      1st       2nd          3rd             4th             5th break  \
# mon  Eng     Hindi  Mathematic              EVS            Art
# tue  Eng  Assembly  Mathematic              EVS            Art
# wed  Eng     Hindi  Mathematic              EVS  Clay modelling
# thu  Eng     Hindi  Mathematic   PE/ CCA Sports           Music
# fri  Eng     Hindi  Mathematic   PE/ CCA Sports           Dance
#
#                               6th 7th dispersal
# mon                       Library
# tue                   Wonder time
# wed  Environmental Education --EE
# thu
# fri
# Processing day: 1st
# Empty slots for Sr. KG on 1st: []
# No empty slots for Sr. KG on 1st, skipping.
# Processing day: 2nd
# Empty slots for Sr. KG on 2nd: []
# No empty slots for Sr. KG on 2nd, skipping.
# Processing day: 3rd
# Empty slots for Sr. KG on 3rd: []
# No empty slots for Sr. KG on 3rd, skipping.
# Processing day: 4th
# Empty slots for Sr. KG on 4th: []
# No empty slots for Sr. KG on 4th, skipping.
# Processing day: 5th
# Empty slots for Sr. KG on 5th: []
# No empty slots for Sr. KG on 5th, skipping.
# Skipping break for Sr. KG as it is not a class day.
# Processing day: 6th
# Empty slots for Sr. KG on 6th: [3, 4]
# Allocated 'Computer Studies / Circle Time' to Sr. KG on 6th, slot 3
# Allocated 'Life Skill / Yoga' to Sr. KG on 6th, slot 4
# Processing day: 7th
# Empty slots for Sr. KG on 7th: [0, 1, 2, 3, 4]
# Allocated 'DEED / Assembly' to Sr. KG on 7th, slot 0
# Allocated 'PLAY PEN  / PLAY PEN ' to Sr. KG on 7th, slot 1
# All pairs allocated for Sr. KG on 7th
# Skipping dispersal for Sr. KG as it is not a class day.
# Processing Sr. KG - B:      1st       2nd          3rd             4th             5th break  \
# mon  Eng     Hindi  Mathematic              EVS            Art
# tue  Eng  Assembly  Mathematic              EVS            Art
# wed  Eng     Hindi  Mathematic              EVS  Clay modelling
# thu  Eng     Hindi  Mathematic   PE/ CCA Sports           Music
# fri  Eng     Hindi  Mathematic   PE/ CCA Sports           Dance
#
#                               6th 7th dispersal
# mon                       Library
# tue                   Wonder time
# wed  Environmental Education --EE
# thu
# fri
# Processing day: 1st
# Empty slots for Sr. KG on 1st: []
# No empty slots for Sr. KG on 1st, skipping.
# Processing day: 2nd
# Empty slots for Sr. KG on 2nd: []
# No empty slots for Sr. KG on 2nd, skipping.
# Processing day: 3rd
# Empty slots for Sr. KG on 3rd: []
# No empty slots for Sr. KG on 3rd, skipping.
# Processing day: 4th
# Empty slots for Sr. KG on 4th: []
# No empty slots for Sr. KG on 4th, skipping.
# Processing day: 5th
# Empty slots for Sr. KG on 5th: []
# No empty slots for Sr. KG on 5th, skipping.
# Skipping break for Sr. KG as it is not a class day.
# Processing day: 6th
# Empty slots for Sr. KG on 6th: [3, 4]
# Allocated 'Computer Studies / Circle Time' to Sr. KG on 6th, slot 3
# Allocated 'Life Skill / Yoga' to Sr. KG on 6th, slot 4
# Processing day: 7th
# Empty slots for Sr. KG on 7th: [0, 1, 2, 3, 4]
# Allocated 'DEED / Assembly' to Sr. KG on 7th, slot 0
# Allocated 'PLAY PEN  / PLAY PEN ' to Sr. KG on 7th, slot 1
# All pairs allocated for Sr. KG on 7th
# Skipping dispersal for Sr. KG as it is not a class day.
# Processing Sr. KG - C:      1st       2nd          3rd             4th             5th break  \
# mon  Eng     Hindi  Mathematic              EVS            Art
# tue  Eng  Assembly  Mathematic              EVS            Art
# wed  Eng     Hindi  Mathematic              EVS  Clay modelling
# thu  Eng     Hindi  Mathematic   PE/ CCA Sports           Music
# fri  Eng     Hindi  Mathematic   PE/ CCA Sports           Dance
#
#                               6th 7th dispersal
# mon                       Library
# tue                   Wonder time
# wed  Environmental Education --EE
# thu
# fri
# Processing day: 1st
# Empty slots for Sr. KG on 1st: []
# No empty slots for Sr. KG on 1st, skipping.
# Processing day: 2nd
# Empty slots for Sr. KG on 2nd: []
# No empty slots for Sr. KG on 2nd, skipping.
# Processing day: 3rd
# Empty slots for Sr. KG on 3rd: []
# No empty slots for Sr. KG on 3rd, skipping.
# Processing day: 4th
# Empty slots for Sr. KG on 4th: []
# No empty slots for Sr. KG on 4th, skipping.
# Processing day: 5th
# Empty slots for Sr. KG on 5th: []
# No empty slots for Sr. KG on 5th, skipping.
# Skipping break for Sr. KG as it is not a class day.
# Processing day: 6th
# Empty slots for Sr. KG on 6th: [3, 4]
# Allocated 'Computer Studies / Circle Time' to Sr. KG on 6th, slot 3
# Allocated 'Life Skill / Yoga' to Sr. KG on 6th, slot 4
# Processing day: 7th
# Empty slots for Sr. KG on 7th: [0, 1, 2, 3, 4]
# Allocated 'DEED / Assembly' to Sr. KG on 7th, slot 0
# Allocated 'PLAY PEN  / PLAY PEN ' to Sr. KG on 7th, slot 1
# All pairs allocated for Sr. KG on 7th
# Skipping dispersal for Sr. KG as it is not a class day.
# Processing Sr. KG - D:      1st       2nd          3rd             4th             5th break  \
# mon  Eng     Hindi  Mathematic              EVS            Art
# tue  Eng  Assembly  Mathematic              EVS            Art
# wed  Eng     Hindi  Mathematic              EVS  Clay modelling
# thu  Eng     Hindi  Mathematic   PE/ CCA Sports           Music
# fri  Eng     Hindi  Mathematic   PE/ CCA Sports           Dance
#
#                               6th 7th dispersal
# mon                       Library
# tue                   Wonder time
# wed  Environmental Education --EE
# thu
# fri
# Processing day: 1st
# Empty slots for Sr. KG on 1st: []
# No empty slots for Sr. KG on 1st, skipping.
# Processing day: 2nd
# Empty slots for Sr. KG on 2nd: []
# No empty slots for Sr. KG on 2nd, skipping.
# Processing day: 3rd
# Empty slots for Sr. KG on 3rd: []
# No empty slots for Sr. KG on 3rd, skipping.
# Processing day: 4th
# Empty slots for Sr. KG on 4th: []
# No empty slots for Sr. KG on 4th, skipping.
# Processing day: 5th
# Empty slots for Sr. KG on 5th: []
# No empty slots for Sr. KG on 5th, skipping.
# Skipping break for Sr. KG as it is not a class day.
# Processing day: 6th
# Empty slots for Sr. KG on 6th: [3, 4]
# Allocated 'Computer Studies / Circle Time' to Sr. KG on 6th, slot 3
# Allocated 'Life Skill / Yoga' to Sr. KG on 6th, slot 4
# Processing day: 7th
# Empty slots for Sr. KG on 7th: [0, 1, 2, 3, 4]
# Allocated 'DEED / Assembly' to Sr. KG on 7th, slot 0
# Allocated 'PLAY PEN  / PLAY PEN ' to Sr. KG on 7th, slot 1
# All pairs allocated for Sr. KG on 7th
# Skipping dispersal for Sr. KG as it is not a class day.
# Processing class: I
# Combined pairs for I: []
# Processing I - A:     HomeRoom  1st    2nd break          3rd          4th          5th  \
# mon           Eng    Eng              Hindi  Mathematic   Mathematic
# tue           Eng    Eng              Hindi  Mathematic      Assembly
# wed           Eng    Eng              Hindi  Mathematic      Marathi
# thu           Eng  Hindi              Hindi  Mathematic      Marathi
# fri           Eng  Hindi        Mathematic   Mathematic           EVS
#
#                   6th               7th             8th break      9th  \
# mon               EVS  Computer Studies            Yoga          Music
# tue               EVS       Circle Time         KARATE         Music T
# wed               EVS        Life Skill            Art           Dance
# thu               EVS    PE/ CCA Sports            Art         Library
# fri  Computer Studies    PE/ CCA Sports  Clay modelling           DEED
#
#                              10th dispersal
# mon                   Wonder time
# tue  Environmental Education --EE
# wed                           SGI
# thu                           SGI
# fri                  CLASS TESTS
# Processing day: HomeRoom
# Empty slots for I on HomeRoom: [0, 1, 2, 3, 4]
# Processing day: 1st
# Empty slots for I on 1st: []
# No empty slots for I on 1st, skipping.
# Processing day: 2nd
# Empty slots for I on 2nd: []
# No empty slots for I on 2nd, skipping.
# Skipping break for I as it is not a class day.
# Processing day: 3rd
# Empty slots for I on 3rd: []
# No empty slots for I on 3rd, skipping.
# Processing day: 4th
# Empty slots for I on 4th: []
# No empty slots for I on 4th, skipping.
# Processing day: 5th
# Empty slots for I on 5th: []
# No empty slots for I on 5th, skipping.
# Processing day: 6th
# Empty slots for I on 6th: []
# No empty slots for I on 6th, skipping.
# Processing day: 7th
# Empty slots for I on 7th: []
# No empty slots for I on 7th, skipping.
# Processing day: 8th
# Empty slots for I on 8th: []
# No empty slots for I on 8th, skipping.
# Skipping break for I as it is not a class day.
# Processing day: 9th
# Empty slots for I on 9th: []
# No empty slots for I on 9th, skipping.
# Processing day: 10th
# Empty slots for I on 10th: []
# No empty slots for I on 10th, skipping.
# Skipping dispersal for I as it is not a class day.
# Processing I - B:     HomeRoom  1st    2nd break          3rd          4th          5th  \
# mon           Eng    Eng              Hindi  Mathematic   Mathematic
# tue           Eng    Eng              Hindi  Mathematic      Assembly
# wed           Eng    Eng              Hindi  Mathematic      Marathi
# thu           Eng  Hindi              Hindi  Mathematic      Marathi
# fri           Eng  Hindi        Mathematic   Mathematic           EVS
#
#                   6th               7th             8th break      9th  \
# mon               EVS  Computer Studies            Yoga          Music
# tue               EVS       Circle Time         KARATE         Music T
# wed               EVS        Life Skill            Art           Dance
# thu               EVS    PE/ CCA Sports            Art         Library
# fri  Computer Studies    PE/ CCA Sports  Clay modelling           DEED
#
#                              10th dispersal
# mon                   Wonder time
# tue  Environmental Education --EE
# wed                           SGI
# thu                           SGI
# fri                  CLASS TESTS
# Processing day: HomeRoom
# Empty slots for I on HomeRoom: [0, 1, 2, 3, 4]
# Processing day: 1st
# Empty slots for I on 1st: []
# No empty slots for I on 1st, skipping.
# Processing day: 2nd
# Empty slots for I on 2nd: []
# No empty slots for I on 2nd, skipping.
# Skipping break for I as it is not a class day.
# Processing day: 3rd
# Empty slots for I on 3rd: []
# No empty slots for I on 3rd, skipping.
# Processing day: 4th
# Empty slots for I on 4th: []
# No empty slots for I on 4th, skipping.
# Processing day: 5th
# Empty slots for I on 5th: []
# No empty slots for I on 5th, skipping.
# Processing day: 6th
# Empty slots for I on 6th: []
# No empty slots for I on 6th, skipping.
# Processing day: 7th
# Empty slots for I on 7th: []
# No empty slots for I on 7th, skipping.
# Processing day: 8th
# Empty slots for I on 8th: []
# No empty slots for I on 8th, skipping.
# Skipping break for I as it is not a class day.
# Processing day: 9th
# Empty slots for I on 9th: []
# No empty slots for I on 9th, skipping.
# Processing day: 10th
# Empty slots for I on 10th: []
# No empty slots for I on 10th, skipping.
# Skipping dispersal for I as it is not a class day.
# Processing I - C:     HomeRoom  1st    2nd break          3rd          4th          5th  \
# mon           Eng    Eng              Hindi  Mathematic   Mathematic
# tue           Eng    Eng              Hindi  Mathematic      Assembly
# wed           Eng    Eng              Hindi  Mathematic      Marathi
# thu           Eng  Hindi              Hindi  Mathematic      Marathi
# fri           Eng  Hindi        Mathematic   Mathematic           EVS
#
#                   6th               7th             8th break      9th  \
# mon               EVS  Computer Studies            Yoga          Music
# tue               EVS       Circle Time         KARATE         Music T
# wed               EVS        Life Skill            Art           Dance
# thu               EVS    PE/ CCA Sports            Art         Library
# fri  Computer Studies    PE/ CCA Sports  Clay modelling           DEED
#
#                              10th dispersal
# mon                   Wonder time
# tue  Environmental Education --EE
# wed                           SGI
# thu                           SGI
# fri                  CLASS TESTS
# Processing day: HomeRoom
# Empty slots for I on HomeRoom: [0, 1, 2, 3, 4]
# <ipython-input-3-ca075d6d4191>:190: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[empty_slots[0]] = pair
# <ipython-input-3-ca075d6d4191>:190: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[empty_slots[0]] = pair
# <ipython-input-3-ca075d6d4191>:190: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[empty_slots[0]] = pair
# <ipython-input-3-ca075d6d4191>:202: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-3-ca075d6d4191>:202: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-3-ca075d6d4191>:202: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-3-ca075d6d4191>:202: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-3-ca075d6d4191>:190: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[empty_slots[0]] = pair
# <ipython-input-3-ca075d6d4191>:190: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[empty_slots[0]] = pair
# <ipython-input-3-ca075d6d4191>:190: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[empty_slots[0]] = pair
# <ipython-input-3-ca075d6d4191>:202: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-3-ca075d6d4191>:202: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-3-ca075d6d4191>:202: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-3-ca075d6d4191>:202: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-3-ca075d6d4191>:190: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[empty_slots[0]] = pair
# <ipython-input-3-ca075d6d4191>:190: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[empty_slots[0]] = pair
# <ipython-input-3-ca075d6d4191>:190: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[empty_slots[0]] = pair
# <ipython-input-3-ca075d6d4191>:202: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-3-ca075d6d4191>:202: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-3-ca075d6d4191>:202: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-3-ca075d6d4191>:202: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-3-ca075d6d4191>:190: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[empty_slots[0]] = pair
# <ipython-input-3-ca075d6d4191>:190: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[empty_slots[0]] = pair
# <ipython-input-3-ca075d6d4191>:190: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[empty_slots[0]] = pair
# <ipython-input-3-ca075d6d4191>:202: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-3-ca075d6d4191>:202: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-3-ca075d6d4191>:202: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-3-ca075d6d4191>:202: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-3-ca075d6d4191>:190: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[empty_slots[0]] = pair
# <ipython-input-3-ca075d6d4191>:190: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[empty_slots[0]] = pair
# <ipython-input-3-ca075d6d4191>:190: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[empty_slots[0]] = pair
# <ipython-input-3-ca075d6d4191>:190: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[empty_slots[0]] = pair
# <ipython-input-3-ca075d6d4191>:202: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-3-ca075d6d4191>:202: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-3-ca075d6d4191>:202: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-3-ca075d6d4191>:190: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[empty_slots[0]] = pair
# <ipython-input-3-ca075d6d4191>:190: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[empty_slots[0]] = pair
# <ipython-input-3-ca075d6d4191>:190: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[empty_slots[0]] = pair
# <ipython-input-3-ca075d6d4191>:190: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[empty_slots[0]] = pair
# <ipython-input-3-ca075d6d4191>:202: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-3-ca075d6d4191>:202: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-3-ca075d6d4191>:202: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-3-ca075d6d4191>:190: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[empty_slots[0]] = pair
# <ipython-input-3-ca075d6d4191>:190: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[empty_slots[0]] = pair
# <ipython-input-3-ca075d6d4191>:190: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[empty_slots[0]] = pair
# <ipython-input-3-ca075d6d4191>:190: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[empty_slots[0]] = pair
# <ipython-input-3-ca075d6d4191>:202: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-3-ca075d6d4191>:202: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-3-ca075d6d4191>:202: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-3-ca075d6d4191>:190: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[empty_slots[0]] = pair
# <ipython-input-3-ca075d6d4191>:190: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[empty_slots[0]] = pair
# <ipython-input-3-ca075d6d4191>:190: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[empty_slots[0]] = pair
# <ipython-input-3-ca075d6d4191>:190: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[empty_slots[0]] = pair
# <ipython-input-3-ca075d6d4191>:202: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-3-ca075d6d4191>:202: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-3-ca075d6d4191>:202: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-3-ca075d6d4191>:202: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-3-ca075d6d4191>:202: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-3-ca075d6d4191>:202: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-3-ca075d6d4191>:202: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-3-ca075d6d4191>:202: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-3-ca075d6d4191>:202: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-3-ca075d6d4191>:202: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-3-ca075d6d4191>:202: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-3-ca075d6d4191>:202: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-3-ca075d6d4191>:202: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-3-ca075d6d4191>:202: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-3-ca075d6d4191>:202: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-3-ca075d6d4191>:202: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-3-ca075d6d4191>:202: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-3-ca075d6d4191>:202: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-3-ca075d6d4191>:202: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-3-ca075d6d4191>:202: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-3-ca075d6d4191>:202: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-3-ca075d6d4191>:202: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# <ipython-input-3-ca075d6d4191>:202: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   periods[i] = "leisure"
# Processing day: 1st
# Empty slots for I on 1st: []
# No empty slots for I on 1st, skipping.
# Processing day: 2nd
# Empty slots for I on 2nd: []
# No empty slots for I on 2nd, skipping.
# Skipping break for I as it is not a class day.
# Processing day: 3rd
# Empty slots for I on 3rd: []
# No empty slots for I on 3rd, skipping.
# Processing day: 4th
# Empty slots for I on 4th: []
# No empty slots for I on 4th, skipping.
# Processing day: 5th
# Empty slots for I on 5th: []
# No empty slots for I on 5th, skipping.
# Processing day: 6th
# Empty slots for I on 6th: []
# No empty slots for I on 6th, skipping.
# Processing day: 7th
# Empty slots for I on 7th: []
# No empty slots for I on 7th, skipping.
# Processing day: 8th
# Empty slots for I on 8th: []
# No empty slots for I on 8th, skipping.
# Skipping break for I as it is not a class day.
# Processing day: 9th
# Empty slots for I on 9th: []
# No empty slots for I on 9th, skipping.
# Processing day: 10th
# Empty slots for I on 10th: []
# No empty slots for I on 10th, skipping.
# Skipping dispersal for I as it is not a class day.
# Processing I - D:     HomeRoom  1st    2nd break          3rd          4th          5th  \
# mon           Eng    Eng              Hindi  Mathematic   Mathematic
# tue           Eng    Eng              Hindi  Mathematic      Assembly
# wed           Eng    Eng              Hindi  Mathematic      Marathi
# thu           Eng  Hindi              Hindi  Mathematic      Marathi
# fri           Eng  Hindi        Mathematic   Mathematic           EVS
#
#                   6th               7th             8th break      9th  \
# mon               EVS  Computer Studies            Yoga          Music
# tue               EVS       Circle Time         KARATE         Music T
# wed               EVS        Life Skill            Art           Dance
# thu               EVS    PE/ CCA Sports            Art         Library
# fri  Computer Studies    PE/ CCA Sports  Clay modelling           DEED
#
#                              10th dispersal
# mon                   Wonder time
# tue  Environmental Education --EE
# wed                           SGI
# thu                           SGI
# fri                  CLASS TESTS
# Processing day: HomeRoom
# Empty slots for I on HomeRoom: [0, 1, 2, 3, 4]
# Processing day: 1st
# Empty slots for I on 1st: []
# No empty slots for I on 1st, skipping.
# Processing day: 2nd
# Empty slots for I on 2nd: []
# No empty slots for I on 2nd, skipping.
# Skipping break for I as it is not a class day.
# Processing day: 3rd
# Empty slots for I on 3rd: []
# No empty slots for I on 3rd, skipping.
# Processing day: 4th
# Empty slots for I on 4th: []
# No empty slots for I on 4th, skipping.
# Processing day: 5th
# Empty slots for I on 5th: []
# No empty slots for I on 5th, skipping.
# Processing day: 6th
# Empty slots for I on 6th: []
# No empty slots for I on 6th, skipping.
# Processing day: 7th
# Empty slots for I on 7th: []
# No empty slots for I on 7th, skipping.
# Processing day: 8th
# Empty slots for I on 8th: []
# No empty slots for I on 8th, skipping.
# Skipping break for I as it is not a class day.
# Processing day: 9th
# Empty slots for I on 9th: []
# No empty slots for I on 9th, skipping.
# Processing day: 10th
# Empty slots for I on 10th: []
# No empty slots for I on 10th, skipping.
# Skipping dispersal for I as it is not a class day.
# Timetables generated and saved successfully.
